# %% [markdown]
# # Progress Metering for Biofuels

# %%
import os
import re
from collections import defaultdict, OrderedDict
import pandas as pd
import numpy as np

# %% [markdown]
# # If you're using this for new results, simply set your default directory and you're good to go

# %%
directory = '../results'
results = defaultdict(OrderedDict)
gotPast6 = []
gotPast9 = []
for i in range(1,73):
    r = results[i]
    filename = 'AutoTST-biofuels-rerun.{0:d}.combined.log'.format(i)
    #filename = 'AutoTST-biofuels.xxx.combined.log'
    filepath = os.path.join(directory,filename)
    if os.path.exists(filepath):
        r['1 log file exists'] = 1
    else:
        continue
    with open(filepath) as f:
        lines = f.readlines()
    for j,l in enumerate(lines):
        #m = re.match('biofuelsTST.py:105 <module> INFO (.*)', l)
        if 'biofuelsSymmetryReRun.py:97' in l:
            m = l.split(' ')[-1][:-1]
            r['0 reaction'] = m
        if 'We have generated a H_Abstraction reaction that matches, and used it to label the atoms' in l:
            r['2 matched H-abstraction'] = 1
        if 'Generating a TS geometry via the direct guess method' in l:
            r['3 started making TS geometry'] = 1
        if 'Reading existing ts file' in l:
            r['4 using existing TS data file'] = 1
        if 'Symmetry input file written to' in l:
            r['5 starting Symmetry calculation'] = 1
        if 'Point group:' in l:
            r['6 Symmetry calc successful'] = 1
            gotPast6.append(str(filepath))
        """if "Running symmetry on the point group calculation has failed." in l:
            filename = 'AutoTST-biofuels-rerun.{0:d}.combined.log'.format(i)
            filepath = os.path.join(directory,filename)
            if os.path.exists(filepath):
                continue"""
        if 'line 295, in saveCoordinatesFromRDMol' in l:
            r['7 saveCoordinatesFromRDMol bug'] = -1
            print ''.join(lines[j-30:])
        if 'CanTherm execution initiated' in l:
            r['9 CanTherm started'] = 1
            gotPast9.append(str(filepath))
        if 'One or both of the barrier heights of' in l:
            r['9a CanTherm barrier height problem'] = -1
        if "Reading existing kinetics file" in l:
            r['A using prior calculation result'] = 1
        if 'Yay, reaction kinetics calculated!!!' in l:
            r['B overall success'] = 1

# %%
df = pd.DataFrame(results)
df
# Out:
#                                                              1   \
# 0 reaction                          OOH(1)+OOH(1)=O2(16)+OO(15)
# 1 log file exists                                             1
# 2 matched H-abstraction                                       1
# 3 started making TS geometry                                  1
# 4 using existing TS data file                                 1
# 5 starting Symmetry calculation                               1
# 6 Symmetry calc successful                                    1
# 9 CanTherm started                                            1
# 9a CanTherm barrier height problem                           -1
# A using prior calculation result                            NaN
# B overall success                                           NaN
#
#                                                                   2   \
# 0 reaction                          C8H18(2)+OOH(1)=OO(15)+C8H17(17)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                    NaN
# 5 starting Symmetry calculation                                  NaN
# 6 Symmetry calc successful                                       NaN
# 9 CanTherm started                                               NaN
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                NaN
#
#                                                                   3   \
# 0 reaction                          OO(15)+C8H17(18)=C8H18(2)+OOH(1)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                      1
# 5 starting Symmetry calculation                                    1
# 6 Symmetry calc successful                                         1
# 9 CanTherm started                                                 1
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                  1
#
#                                                                   4   \
# 0 reaction                          OO(15)+C8H17(19)=C8H18(2)+OOH(1)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                      1
# 5 starting Symmetry calculation                                    1
# 6 Symmetry calc successful                                         1
# 9 CanTherm started                                                 1
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                  1
#
#                                                                   5   \
# 0 reaction                          OO(15)+C8H17(20)=C8H18(2)+OOH(1)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                    NaN
# 5 starting Symmetry calculation                                  NaN
# 6 Symmetry calc successful                                       NaN
# 9 CanTherm started                                               NaN
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                NaN
#
#                                                                   6   \
# 0 reaction                          C8H18(3)+OOH(1)=OO(15)+C8H17(21)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                    NaN
# 5 starting Symmetry calculation                                  NaN
# 6 Symmetry calc successful                                       NaN
# 9 CanTherm started                                               NaN
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                NaN
#
#                                                                   7   \
# 0 reaction                          C8H18(3)+OOH(1)=OO(15)+C8H17(22)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                    NaN
# 5 starting Symmetry calculation                                  NaN
# 6 Symmetry calc successful                                       NaN
# 9 CanTherm started                                               NaN
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                NaN
#
#                                                                   8   \
# 0 reaction                          OO(15)+C8H17(23)=C8H18(3)+OOH(1)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                    NaN
# 5 starting Symmetry calculation                                  NaN
# 6 Symmetry calc successful                                       NaN
# 9 CanTherm started                                               NaN
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                NaN
#
#                                                                   9   \
# 0 reaction                          OO(15)+C8H17(24)=C8H18(3)+OOH(1)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                      1
# 5 starting Symmetry calculation                                    1
# 6 Symmetry calc successful                                         1
# 9 CanTherm started                                                 1
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                  1
#
#                                                                   10  \
# 0 reaction                          OO(15)+C8H17(25)=C8H18(3)+OOH(1)
# 1 log file exists                                                  1
# 2 matched H-abstraction                                            1
# 3 started making TS geometry                                       1
# 4 using existing TS data file                                      1
# 5 starting Symmetry calculation                                    1
# 6 Symmetry calc successful                                         1
# 9 CanTherm started                                                 1
# 9a CanTherm barrier height problem                               NaN
# A using prior calculation result                                 NaN
# B overall success                                                  1
#
#                                                    ...                   \
# 0 reaction                                         ...
# 1 log file exists                                  ...
# 2 matched H-abstraction                            ...
# 3 started making TS geometry                       ...
# 4 using existing TS data file                      ...
# 5 starting Symmetry calculation                    ...
# 6 Symmetry calc successful                         ...
# 9 CanTherm started                                 ...
# 9a CanTherm barrier height problem                 ...
# A using prior calculation result                   ...
# B overall success                                  ...
#
#                                                            63  \
# 0 reaction                          OO(15)+S(78)=OOH(1)+S(13)
# 1 log file exists                                           1
# 2 matched H-abstraction                                     1
# 3 started making TS geometry                                1
# 4 using existing TS data file                             NaN
# 5 starting Symmetry calculation                           NaN
# 6 Symmetry calc successful                                NaN
# 9 CanTherm started                                        NaN
# 9a CanTherm barrier height problem                        NaN
# A using prior calculation result                          NaN
# B overall success                                         NaN
#
#                                                            64  \
# 0 reaction                          OO(15)+S(79)=OOH(1)+S(13)
# 1 log file exists                                           1
# 2 matched H-abstraction                                     1
# 3 started making TS geometry                                1
# 4 using existing TS data file                             NaN
# 5 starting Symmetry calculation                           NaN
# 6 Symmetry calc successful                                NaN
# 9 CanTherm started                                        NaN
# 9a CanTherm barrier height problem                        NaN
# A using prior calculation result                          NaN
# B overall success                                         NaN
#
#                                                            65  \
# 0 reaction                          OO(15)+S(80)=OOH(1)+S(13)
# 1 log file exists                                           1
# 2 matched H-abstraction                                     1
# 3 started making TS geometry                                1
# 4 using existing TS data file                             NaN
# 5 starting Symmetry calculation                           NaN
# 6 Symmetry calc successful                                NaN
# 9 CanTherm started                                        NaN
# 9a CanTherm barrier height problem                        NaN
# A using prior calculation result                          NaN
# B overall success                                         NaN
#
#                                                            66  \
# 0 reaction                          OO(15)+S(81)=OOH(1)+S(13)
# 1 log file exists                                           1
# 2 matched H-abstraction                                     1
# 3 started making TS geometry                                1
# 4 using existing TS data file                             NaN
# 5 starting Symmetry calculation                           NaN
# 6 Symmetry calc successful                                NaN
# 9 CanTherm started                                        NaN
# 9a CanTherm barrier height problem                        NaN
# A using prior calculation result                          NaN
# B overall success                                         NaN
#
#                                                            67  \
# 0 reaction                          OO(15)+S(82)=OOH(1)+S(13)
# 1 log file exists                                           1
# 2 matched H-abstraction                                     1
# 3 started making TS geometry                                1
# 4 using existing TS data file                             NaN
# 5 starting Symmetry calculation                           NaN
# 6 Symmetry calc successful                                NaN
# 9 CanTherm started                                        NaN
# 9a CanTherm barrier height problem                        NaN
# A using prior calculation result                          NaN
# B overall success                                         NaN
#
#                                                                      68  \
# 0 reaction                          OO(15)+C8H17O(83)=OOH(1)+C8H18O(14)
# 1 log file exists                                                     1
# 2 matched H-abstraction                                               1
# 3 started making TS geometry                                          1
# 4 using existing TS data file                                       NaN
# 5 starting Symmetry calculation                                     NaN
# 6 Symmetry calc successful                                          NaN
# 9 CanTherm started                                                  NaN
# 9a CanTherm barrier height problem                                  NaN
# A using prior calculation result                                    NaN
# B overall success                                                   NaN
#
#                                                                      69  \
# 0 reaction                          OO(15)+C8H17O(84)=OOH(1)+C8H18O(14)
# 1 log file exists                                                     1
# 2 matched H-abstraction                                               1
# 3 started making TS geometry                                          1
# 4 using existing TS data file                                       NaN
# 5 starting Symmetry calculation                                     NaN
# 6 Symmetry calc successful                                          NaN
# 9 CanTherm started                                                  NaN
# 9a CanTherm barrier height problem                                  NaN
# A using prior calculation result                                    NaN
# B overall success                                                   NaN
#
#                                                                      70  \
# 0 reaction                          OO(15)+C8H17O(85)=OOH(1)+C8H18O(14)
# 1 log file exists                                                     1
# 2 matched H-abstraction                                               1
# 3 started making TS geometry                                          1
# 4 using existing TS data file                                       NaN
# 5 starting Symmetry calculation                                     NaN
# 6 Symmetry calc successful                                          NaN
# 9 CanTherm started                                                  NaN
# 9a CanTherm barrier height problem                                  NaN
# A using prior calculation result                                    NaN
# B overall success                                                   NaN
#
#                                                                      71  \
# 0 reaction                          OO(15)+C8H17O(86)=OOH(1)+C8H18O(14)
# 1 log file exists                                                     1
# 2 matched H-abstraction                                               1
# 3 started making TS geometry                                          1
# 4 using existing TS data file                                       NaN
# 5 starting Symmetry calculation                                     NaN
# 6 Symmetry calc successful                                          NaN
# 9 CanTherm started                                                  NaN
# 9a CanTherm barrier height problem                                  NaN
# A using prior calculation result                                    NaN
# B overall success                                                   NaN
#
#                                                                      72
# 0 reaction                          OO(15)+C8H17O(87)=OOH(1)+C8H18O(14)
# 1 log file exists                                                     1
# 2 matched H-abstraction                                               1
# 3 started making TS geometry                                          1
# 4 using existing TS data file                                       NaN
# 5 starting Symmetry calculation                                     NaN
# 6 Symmetry calc successful                                          NaN
# 9 CanTherm started                                                  NaN
# 9a CanTherm barrier height problem                                  NaN
# A using prior calculation result                                    NaN
# B overall success                                                   NaN
#
# [11 rows x 72 columns]

# %%
i = 0
for j,l in enumerate(lines):
    l = str(l)
    print l
    if 'biofuelsTST.py:105 <module> INFO' in l:
        print "yay"
        i += 1
    else:
        print "boo"
# Out:
# biofuelsSymmetryReRun.py:32 <module> INFO RUNNING WITH JOB NUMBER i = 72
#
# boo
# biofuelsSymmetryReRun.py:36 <module> INFO Previous .combined.log file loaded
#
# boo
# biofuelsSymmetryReRun.py:49 <module> INFO A symmetry issue exists. Continuing calculations on it.
#
# boo
# biofuelsSymmetryReRun.py:53 <module> INFO Loading RMG Database ...
#
# boo
# biofuelsSymmetryReRun.py:56 <module> INFO /home/harms.n/Code/RMG-database/input
#
# boo
# thermo.py:760 loadLibraries INFO Loading thermodynamics library from thermo_DFT_CCSDTF12_BAC.py in /home/harms.n/Code/RMG-database/input/thermo/libraries...
#
# boo
# thermo.py:760 loadLibraries INFO Loading thermodynamics library from CBS_QB3_1dHR.py in /home/harms.n/Code/RMG-database/input/thermo/libraries...
#
# boo
# thermo.py:760 loadLibraries INFO Loading thermodynamics library from primaryThermoLibrary.py in /home/harms.n/Code/RMG-database/input/thermo/libraries...
#
# boo
# thermo.py:760 loadLibraries INFO Loading thermodynamics library from KlippensteinH2O2.py in /home/harms.n/Code/RMG-database/input/thermo/libraries...
#
# boo
# thermo.py:774 loadGroups INFO Loading thermodynamics group database from /home/harms.n/Code/RMG-database/input/thermo/groups...
#
# boo
# transport.py:294 loadGroups INFO Loading transport group database from /home/harms.n/Code/RMG-database/input/transport/groups...
#
# boo
# database.py:165 loadFamilies INFO Loading the user-specified kinetics families from /home/harms.n/Code/RMG-database/input/kinetics/families
#
# boo
# statmech.py:526 loadGroups INFO Loading frequencies group database from /home/harms.n/Code/RMG-database/input/statmech/groups...
#
# boo
# biofuelsSymmetryReRun.py:65 <module> INFO RMG Database Loaded
#
# boo
# biofuelsSymmetryReRun.py:70 <module> INFO Species Dictionary loaded
#
# boo
# biofuelsSymmetryReRun.py:74 <module> INFO Chemkin loaded
#
# boo
# biofuelsSymmetryReRun.py:88 <module> INFO [('H_Abstraction', 'OOH(1)+OOH(1)=O2(16)+OO(15)                         3.500e+10 0.000     -3.275   \n'), ('H_Abstraction', 'C8H18(2)+OOH(1)=OO(15)+C8H17(17)                    2.800e+12 0.000     16.013   \n'), ('H_Abstraction', 'OO(15)+C8H17(18)=C8H18(2)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(19)=C8H18(2)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C8H17(20)=C8H18(2)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'C8H18(3)+OOH(1)=OO(15)+C8H17(21)                    2.800e+12 0.000     16.013   \n'), ('H_Abstraction', 'C8H18(3)+OOH(1)=OO(15)+C8H17(22)                    2.800e+12 0.000     16.013   \n'), ('H_Abstraction', 'OO(15)+C8H17(23)=C8H18(3)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(24)=C8H18(3)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(25)=C8H18(3)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C8H17(26)=C8H18(3)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C8H17(27)=C8H18(3)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'C8H18(4)+OOH(1)=OO(15)+C8H17(28)                    2.800e+12 0.000     16.013   \n'), ('H_Abstraction', 'OO(15)+C8H17(29)=C8H18(4)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(30)=C8H18(4)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(31)=C8H18(4)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(32)=C8H18(4)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C8H17(33)=C8H18(4)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C8H17(34)=C8H18(4)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C8H17(35)=C8H18(4)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C5H11O(36)=C5H12O(5)+OOH(1)                  1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C5H11O(37)=C5H12O(5)+OOH(1)                  4.200e-01 3.530     1.560    \n'), ('H_Abstraction', 'OO(15)+C5H11O(38)=C5H12O(5)+OOH(1)                  1.150e+01 2.940     0.460    \n'), ('H_Abstraction', 'OO(15)+C5H11O(39)=C5H12O(5)+OOH(1)                  1.134e-01 3.855     8.760    \n'), ('H_Abstraction', 'OO(15)+C6H13O(40)=C6H14O(6)+OOH(1)                  2.910e+00 3.310     1.410    \n'), ('H_Abstraction', 'OO(15)+C6H13O(41)=C6H14O(6)+OOH(1)                  1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C6H13O(42)=C6H14O(6)+OOH(1)                  1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C6H13O(43)=C6H14O(6)+OOH(1)                  5.700e+01 3.040     1.210    \n'), ('H_Abstraction', 'OO(15)+C6H13O(44)=C6H14O(6)+OOH(1)                  6.110e-01 3.530     1.520    \n'), ('H_Abstraction', 'OO(15)+C6H13O(45)=C6H14O(6)+OOH(1)                  3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C6H13O(46)=C6H14O(6)+OOH(1)                  1.134e-01 3.855     8.760    \n'), ('H_Abstraction', 'C9H18(7)+OOH(1)=OO(15)+C9H17(47)                    1.330e+11 0.000     11.300   \n'), ('H_Abstraction', 'OO(15)+C9H17(48)=C9H18(7)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C9H17(49)=C9H18(7)+OOH(1)                    1.660e-07 5.407     0.040    \n'), ('H_Abstraction', 'OO(15)+C9H17(50)=C9H18(7)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'OO(15)+C9H17(51)=C9H18(7)+OOH(1)                    3.000e+00 3.280     1.050    \n'), ('H_Abstraction', 'C9H18(7)+OOH(1)=OO(15)+C9H17(52)                    3.470e-03 4.650     9.780    \n'), ('H_Abstraction', 'OO(15)+C9H17(53) ...
#
# boo
# biofuelsSymmetryReRun.py:89 <module> INFO <type 'list'>
#
# boo
# biofuelsSymmetryReRun.py:91 <module> INFO Reaction list generated
#
# boo
# biofuelsSymmetryReRun.py:96 <module> INFO This reaction:
#
# boo
# biofuelsSymmetryReRun.py:97 <module> INFO OO(15)+C8H17O(87)=OOH(1)+C8H18O(14)
#
# boo
# biofuelsSymmetryReRun.py:98 <module> INFO 'OO(15)+C8H17O(87)=OOH(1)+C8H18O(14)'
#
# boo
# biofuelsSymmetryReRun.py:99 <module> INFO OO(15)+C8H17O(87)
#
# boo
# biofuelsSymmetryReRun.py:100 <module> INFO OOH(1)+C8H18O(14)
#
# boo
# biofuelsSymmetryReRun.py:117 <module> INFO generateReactionsFromFamilies successfuly performed
#
# boo
# biofuelsSymmetryReRun.py:190 performCalcs INFO chemkinRxn: Reaction(reactants=[Molecule(SMILES="OO"), Molecule(SMILES="[CH2]CC(CC)OC(C)C")], products=[Molecule(SMILES="CCC(CC)OC(C)C"), Molecule(SMILES="[O]O")], degeneracy=2, pairs=[[Molecule(SMILES="OO"), Molecule(SMILES="[O]O")], [Molecule(SMILES="[CH2]CC(CC)OC(C)C"), Molecule(SMILES="CCC(CC)OC(C)C")]])
#
# boo
# biofuelsSymmetryReRun.py:192 performCalcs INFO Ensuring resonance isomers have been generated
#
# boo
# biofuelsSymmetryReRun.py:211 performCalcs INFO Generated one reaction:
#
# boo
# biofuelsSymmetryReRun.py:212 performCalcs INFO [Reaction(reactants=[Molecule(SMILES="OO"), Molecule(SMILES="[CH2]CC(CC)OC(C)C")], products=[Molecule(SMILES="CCC(CC)OC(C)C"), Molecule(SMILES="[O]O")], degeneracy=2, pairs=[[Molecule(SMILES="OO"), Molecule(SMILES="[O]O")], [Molecule(SMILES="[CH2]CC(CC)OC(C)C"), Molecule(SMILES="CCC(CC)OC(C)C")]])]
#
# boo
# biofuelsSymmetryReRun.py:221 performCalcs INFO The reaction of interest is as follows:
#
# boo
# biofuelsSymmetryReRun.py:222 performCalcs INFO <Molecule "OO"> + <Molecule "[CH2]CC(CC)OC(C)C"> <=> <Molecule "CCC(CC)OC(C)C"> + <Molecule "[O]O">
#
# boo
# biofuelsSymmetryReRun.py:224 performCalcs INFO asserting that the testReaction is Isomorphic
#
# boo
# biofuelsSymmetryReRun.py:226 performCalcs INFO reaction: Reaction(reactants=[Molecule(SMILES="OO"), Molecule(SMILES="[CH2]CC(CC)OC(C)C")], products=[Molecule(SMILES="CCC(CC)OC(C)C"), Molecule(SMILES="[O]O")], degeneracy=2, pairs=[[Molecule(SMILES="OO"), Molecule(SMILES="[O]O")], [Molecule(SMILES="[CH2]CC(CC)OC(C)C"), Molecule(SMILES="CCC(CC)OC(C)C")]])
#
# boo
# biofuelsSymmetryReRun.py:232 performCalcs INFO Labeling reactant atoms
#
# boo
# biofuelsSymmetryReRun.py:242 performCalcs INFO Labeling product atoms
#
# boo
# biofuelsSymmetryReRun.py:258 performCalcs INFO We have generated a H_Abstraction reaction that matches, and used it to label the atoms.
#
# boo
# biofuelsSymmetryReRun.py:260 performCalcs INFO Calculating reaction kinetics
#
# boo
# biofuelsSymmetryReRun.py:167 calculate INFO Calculating reaction rate for <Molecule "OO"> + <Molecule "[CH2]CC(CC)OC(C)C"> <=> <Molecule "CCC(CC)OC(C)C"> + <Molecule "[O]O">
#
# boo
# biofuelsSymmetryReRun.py:169 calculate INFO Selecting the appropriate TS distance database for family 'H_Abstraction'
#
# boo
# biofuelsSymmetryReRun.py:171 calculate INFO Calculating kinetic data by calling qmCalc.getKineticData
#
# boo
# reaction.py:619 loadKineticsData INFO Kinetics results file /gss_gpfs_scratch/harms.n/QMfiles/OO+[CH2]CC(CC)OC(C)C_CCC(CC)OC(C)C+[O]O.kinetics does not exist or is invalid
#
# boo
# reaction.py:520 generateTSGeometryDirectGuess INFO Generating a TS geometry via the direct guess method
#
# boo
# reaction.py:300 generateBoundsMatrix INFO Generating bounds matrix for OO.[CH2]CC(CC)OC(C)C
#
# boo
# reaction.py:338 bmPreEdit INFO Changing lower limit 3.15 to 2.812396
#
# boo
# reaction.py:338 bmPreEdit INFO Changing lower limit 2.519563 to 2.456764
#
# boo
# reaction.py:338 bmPreEdit INFO Changing lower limit 3.65 to 3.22113913735
#
# boo
# reaction.py:561 generateTSGeometryDirectGuess INFO TS estimate made. About to try the search...
#
# boo
# reaction.py:426 optimizeTS INFO Starting optimization steps of the TS search.
#
# boo
# gaussian.py:535 optEstimate INFO Running loose optimization of TS with frozen center
#
# boo
# gaussian.py:189 writeInputFile INFO Writing gaussian input file /gss_gpfs_scratch/harms.n/QMscratch/OO+[CH2]CC(CC)OC(C)C_CCC(CC)OC(C)C+[O]OEst.gjf
#
# boo
# Traceback (most recent call last):
#
# boo
#   File "/home/harms.n/Code/OOHabstraction/Biofuels/biofuelsSymmetryReRun.py", line 350, in <module>
#
# boo
#     performCalcs(rxn)
#
# boo
#   File "/home/harms.n/Code/OOHabstraction/Biofuels/biofuelsSymmetryReRun.py", line 261, in performCalcs
#
# boo
#     reaction = calculate(reaction)
#
# boo
#   File "/home/harms.n/Code/OOHabstraction/Biofuels/biofuelsSymmetryReRun.py", line 172, in calculate
#
# boo
#     reaction = qmCalc.getKineticData(reaction, tsDatabase)
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/main.py", line 251, in getKineticData
#
# boo
#     reaction = qm_reaction_calculator.generateKineticData()
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/reaction.py", line 838, in generateKineticData
#
# boo
#     tsFound = self.generateTSGeometryDirectGuess()
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/reaction.py", line 562, in generateTSGeometryDirectGuess
#
# boo
#     check =  self.tsSearch(labels)
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/reaction.py", line 502, in tsSearch
#
# boo
#     successfulTS = self.optimizeTS(labels)
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/reaction.py", line 440, in optimizeTS
#
# boo
#     optEst = self.optEstimate(labels)
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/gaussian.py", line 579, in optEstimate
#
# boo
#     outputFilePath = self.runAlt(inputFilePath)
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/gaussian.py", line 675, in runAlt
#
# boo
#     self.testReady()
#
# boo
#   File "/home/harms.n/Code/RMG-Py/rmgpy/qm/gaussian.py", line 72, in testReady
#
# boo
#     raise Exception("Couldn't find Gaussian executable at {0}. Try setting your GAUSS_EXEDIR environment variable.".format(self.executablePath))
#
# boo
# Exception: Couldn't find Gaussian executable at /shared/apps/gaussian/G09_LINUX_LINDA/g09/bsd:/shared/apps/gaussian/G09_LINUX_LINDA/g09/local:/shared/apps/gaussian/G09_LINUX_LINDA/g09/extras:/shared/apps/gaussian/G09_LINUX_LINDA/g09/(Gaussian 2003 or 2009). Try setting your GAUSS_EXEDIR environment variable.
#
# boo

# %%
df.sum(axis=1)
# Out:
# 0 reaction                            OOH(1)+OOH(1)=O2(16)+OO(15)C8H18(2)+OOH(1)=OO(...
# 1 log file exists                                                                    72
# 2 matched H-abstraction                                                              72
# 3 started making TS geometry                                                         64
# 4 using existing TS data file                                                        18
# 5 starting Symmetry calculation                                                      18
# 6 Symmetry calc successful                                                           18
# 9 CanTherm started                                                                   11
# 9a CanTherm barrier height problem                                                   -2
# A using prior calculation result                                                      8
# B overall success                                                                    17
# dtype: object

# %%
df.count(axis=1)
# Out:
# 0 reaction                            72
# 1 log file exists                     72
# 2 matched H-abstraction               72
# 3 started making TS geometry          64
# 4 using existing TS data file         18
# 5 starting Symmetry calculation       18
# 6 Symmetry calc successful            18
# 9 CanTherm started                    11
# 9a CanTherm barrier height problem     2
# A using prior calculation result       8
# B overall success                     17
# dtype: int64

# %%
for i in range(len(df.columns)):
    if np.isnan(df.iloc[-1,i]) == False:
        print df.iloc[-1,i]
        print df.iloc[0,i]
# Out:
# 1
# OO(15)+C8H17(18)=C8H18(2)+OOH(1)
# 1
# OO(15)+C8H17(19)=C8H18(2)+OOH(1)
# 1
# OO(15)+C8H17(24)=C8H18(3)+OOH(1)
# 1
# OO(15)+C8H17(25)=C8H18(3)+OOH(1)
# 1
# OO(15)+C8H17(26)=C8H18(3)+OOH(1)
# 1
# C8H18(4)+OOH(1)=OO(15)+C8H17(28)
# 1
# OO(15)+C8H17(29)=C8H18(4)+OOH(1)
# 1
# OO(15)+C8H17(30)=C8H18(4)+OOH(1)
# 1
# OO(15)+C8H17(32)=C8H18(4)+OOH(1)
# 1
# OO(15)+C8H17(33)=C8H18(4)+OOH(1)
# 1
# OO(15)+C6H13O(41)=C6H14O(6)+OOH(1)
# 1
# OO(15)+C6H13O(42)=C6H14O(6)+OOH(1)
# 1
# OO(15)+C6H13O(43)=C6H14O(6)+OOH(1)
# 1
# OO(15)+C6H13O(44)=C6H14O(6)+OOH(1)
# 1
# OO(15)+C6H13O(46)=C6H14O(6)+OOH(1)
# 1
# OO(15)+C6H11(54)=C6H12(8)+OOH(1)
# 1
# OO(15)+C6H11(55)=C6H12(8)+OOH(1)

# %% [markdown]
# ## This part is used to try and figure out why some log files didn't make it from step 6 to step 9

# %%
df.loc['A using prior calculation result'][df.loc['3 started making TS geometry']!=1]
# Out:
# 13    1
# 14    1
# 15    1
# 17    1
# 18    1
# 31    1
# 39    1
# 40    1
# Name: A using prior calculation result, dtype: object

# %% [markdown]
# The eight that did NOT have step 3 "started making TS geometry" all had "A using prior calculation result" i.e. they had worked, on a previous iteration. For example:

# %%
df[13]
# Out:
# 0 reaction                            C8H18(4)+OOH(1)=OO(15)+C8H17(28)
# 1 log file exists                                                    1
# 2 matched H-abstraction                                              1
# 3 started making TS geometry                                       NaN
# 4 using existing TS data file                                      NaN
# 5 starting Symmetry calculation                                    NaN
# 6 Symmetry calc successful                                         NaN
# 9 CanTherm started                                                 NaN
# 9a CanTherm barrier height problem                                 NaN
# A using prior calculation result                                     1
# B overall success                                                    1
# Name: 13, dtype: object

# %%
# Which had at least one successful symmetry but did not start cantherm
df.loc['0 reaction'][(df.loc['9 CanTherm started']!=1) & (df.loc['6 Symmetry calc successful']==1) ]
# Out:
# 12      OO(15)+C8H17(27)=C8H18(3)+OOH(1)
# 19      OO(15)+C8H17(34)=C8H18(4)+OOH(1)
# 20      OO(15)+C8H17(35)=C8H18(4)+OOH(1)
# 21    OO(15)+C5H11O(36)=C5H12O(5)+OOH(1)
# 22    OO(15)+C5H11O(37)=C5H12O(5)+OOH(1)
# 23    OO(15)+C5H11O(38)=C5H12O(5)+OOH(1)
# 24    OO(15)+C5H11O(39)=C5H12O(5)+OOH(1)
# Name: 0 reaction, dtype: object

# %% [markdown]
# * 12 weird cclib parsing error. suggest we try again
# * 19 looks like it got interrupted on one of the molecules: [CH2]CCCC(C)CC. no errors reported, just stopped
# * 20 looks like it got interrupted on one of the molecules: [CH2]CC(C)CCCC. no errors reported, just stopped
# * 21 looks like it got interrupted on one of the molecules: CCC(C)(C)O
# * 22 looks like it got interrupted on one of the molecules: CCC(C)(C)O
# * 23 looks like it got interrupted on one of the molecules: CCC(C)(C)O. race condition with 22?
# * 24 looks like it got interrupted on one of the molecules: CCC(C)(C)[O]

# %%
gotPast6
# Out:
# ['./results/AutoTST-biofuels-rerun.1.combined.log',
#  './results/AutoTST-biofuels-rerun.1.combined.log',
#  './results/AutoTST-biofuels-rerun.1.combined.log',
#  './results/AutoTST-biofuels-rerun.1.combined.log',
#  './results/AutoTST-biofuels-rerun.3.combined.log',
#  './results/AutoTST-biofuels-rerun.3.combined.log',
#  './results/AutoTST-biofuels-rerun.3.combined.log',
#  './results/AutoTST-biofuels-rerun.3.combined.log',
#  './results/AutoTST-biofuels-rerun.4.combined.log',
#  './results/AutoTST-biofuels-rerun.4.combined.log',
#  './results/AutoTST-biofuels-rerun.4.combined.log',
#  './results/AutoTST-biofuels-rerun.4.combined.log',
#  './results/AutoTST-biofuels-rerun.9.combined.log',
#  './results/AutoTST-biofuels-rerun.9.combined.log',
#  './results/AutoTST-biofuels-rerun.9.combined.log',
#  './results/AutoTST-biofuels-rerun.9.combined.log',
#  './results/AutoTST-biofuels-rerun.10.combined.log',
#  './results/AutoTST-biofuels-rerun.10.combined.log',
#  './results/AutoTST-biofuels-rerun.10.combined.log',
#  './results/AutoTST-biofuels-rerun.10.combined.log',
#  './results/AutoTST-biofuels-rerun.11.combined.log',
#  './results/AutoTST-biofuels-rerun.11.combined.log',
#  './results/AutoTST-biofuels-rerun.11.combined.log',
#  './results/AutoTST-biofuels-rerun.11.combined.log',
#  './results/AutoTST-biofuels-rerun.12.combined.log',
#  './results/AutoTST-biofuels-rerun.12.combined.log',
#  './results/AutoTST-biofuels-rerun.19.combined.log',
#  './results/AutoTST-biofuels-rerun.20.combined.log',
#  './results/AutoTST-biofuels-rerun.21.combined.log',
#  './results/AutoTST-biofuels-rerun.21.combined.log',
#  './results/AutoTST-biofuels-rerun.22.combined.log',
#  './results/AutoTST-biofuels-rerun.22.combined.log',
#  './results/AutoTST-biofuels-rerun.23.combined.log',
#  './results/AutoTST-biofuels-rerun.23.combined.log',
#  './results/AutoTST-biofuels-rerun.24.combined.log',
#  './results/AutoTST-biofuels-rerun.26.combined.log',
#  './results/AutoTST-biofuels-rerun.26.combined.log',
#  './results/AutoTST-biofuels-rerun.26.combined.log',
#  './results/AutoTST-biofuels-rerun.26.combined.log',
#  './results/AutoTST-biofuels-rerun.27.combined.log',
#  './results/AutoTST-biofuels-rerun.27.combined.log',
#  './results/AutoTST-biofuels-rerun.27.combined.log',
#  './results/AutoTST-biofuels-rerun.27.combined.log',
#  './results/AutoTST-biofuels-rerun.28.combined.log',
#  './results/AutoTST-biofuels-rerun.28.combined.log',
#  './results/AutoTST-biofuels-rerun.28.combined.log',
#  './results/AutoTST-biofuels-rerun.28.combined.log',
#  './results/AutoTST-biofuels-rerun.29.combined.log',
#  './results/AutoTST-biofuels-rerun.29.combined.log',
#  './results/AutoTST-biofuels-rerun.29.combined.log',
#  './results/AutoTST-biofuels-rerun.29.combined.log',
#  './results/AutoTST-biofuels-rerun.30.combined.log',
#  './results/AutoTST-biofuels-rerun.30.combined.log',
#  './results/AutoTST-biofuels-rerun.30.combined.log',
#  './results/AutoTST-biofuels-rerun.30.combined.log']

# %%
gotPast9
# Out:
# ['./results/AutoTST-biofuels-rerun.1.combined.log',
#  './results/AutoTST-biofuels-rerun.3.combined.log',
#  './results/AutoTST-biofuels-rerun.4.combined.log',
#  './results/AutoTST-biofuels-rerun.9.combined.log',
#  './results/AutoTST-biofuels-rerun.10.combined.log',
#  './results/AutoTST-biofuels-rerun.11.combined.log',
#  './results/AutoTST-biofuels-rerun.26.combined.log',
#  './results/AutoTST-biofuels-rerun.27.combined.log',
#  './results/AutoTST-biofuels-rerun.28.combined.log',
#  './results/AutoTST-biofuels-rerun.29.combined.log',
#  './results/AutoTST-biofuels-rerun.30.combined.log']
