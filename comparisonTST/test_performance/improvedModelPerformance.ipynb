# %%
import sys
from pyteck.eval_model import evaluate_model

# %%
model = 'ConstrainedModelRates.cti'
species_key = 'species-keys.yaml'
data_path = 'data'
data_list = 'nbutanol-datalist.txt'
model_path = 'models'

# %%
output = evaluate_model(model, spec_keys_file='species-keys.yaml',
                        dataset_file=data_list, data_path=data_path,
                        model_path=model_path,
                        skip_validation=False
                            )
# Out:
# Warning: multiple changing variables. Using temperature.
# Standard deviation of 0.00 too low, using 0.10
# Done with case  Bec_phi_0.71_n-b_0.0338_xO2_0.284_2
# Done with case  Bec_phi_0.71_n-b_0.0338_xO2_0.284_1
# Done with case  Bec_phi_0.71_n-b_0.0338_xO2_0.284_0
# Warning: multiple changing variables. Using temperature.
# Standard deviation of 0.07 too low, using 0.10
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_1
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_0
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_2
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_4
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_3
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_5
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_6
# Done with case  Bec_phi_0.72_n-b_0.0172_xO2_0.144_7
# Warning: multiple changing variables. Using temperature.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-5840207444cd> in <module>()
#       2                         dataset_file=data_list, data_path=data_path,
#       3                         model_path=model_path,
# ----> 4                         skip_validation=False
#       5                             )
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pyteck/eval_model.py in evaluate_model(model_name, spec_keys_file, dataset_file, data_path, model_path, results_path, model_variant_file, num_threads, print_results, restart, skip_validation)
#     263         variable = get_changing_variable(properties.datapoints)
#     264         # for ignition delay, use logarithm of values
# --> 265         standard_dev = estimate_std_dev(variable, numpy.log(ign_delay))
#     266         dataset_meta['standard deviation'] = float(standard_dev)
#     267
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pyteck/eval_model.py in estimate_std_dev(indep_variable, dep_variable)
#     115         spline = UnivariateSpline(indep_variable, dep_variable, k=2)
#     116     else:
# --> 117         spline = UnivariateSpline(indep_variable, dep_variable)
#     118
#     119     standard_dev = numpy.std(dep_variable - spline(indep_variable))
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py in __init__(self, x, y, w, bbox, k, s, ext, check_finite)
#     174                 raise ValueError("x and y array must not contain NaNs or infs.")
#     175         if not all(diff(x) > 0.0):
# --> 176             raise ValueError('x must be strictly increasing')
#     177
#     178         # _data == x,y,w,xb,xe,k,s,n,t,c,fp,fpint,nrdata,ier
#
# ValueError: x must be strictly increasing
