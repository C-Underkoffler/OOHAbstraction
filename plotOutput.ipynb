# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

import numpy as np
import os, sys
rmg_path = os.getenv('RMGpy')
if rmg_path and rmg_path not in sys.path:
    sys.path.insert(1,rmg_path)

import rmgpy.kinetics

# %%
workbookPath = '/gss_gpfs_scratch/westgroup/Importer/RMG-models/modelComparer/output.xls'
kineticsSheet = pd.read_excel('outputTest.xls', sheetname='k-1000K-100bar', header=4).iloc[:,1:-5]
expressionSheet = pd.read_excel('outputTest.xls', sheetname='k-expressions', header=4).iloc[:,1:]

# %% [markdown]
# ## Making the box plot

# %%
rxnList = kineticsSheet['AutoTST-OOHabstraction'].dropna().index.values
kinSheet = kineticsSheet.ix[rxnList].sort(columns='AutoTST-OOHabstraction').set_index('Reaction')
kinSheet
# Out:
# /Users/nathan/anaconda/envs/rmg_env/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                           PCI2013/353-Malewicki  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                   2.816148
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                          NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                        1.422766
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                       2.422766
# C4H10 + HO2 <=> PC4H9 + H2O2                           2.760965
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                           NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                     0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                     2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                            NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                          2.937057
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                           NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                          NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                     2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                         NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                        2.297818
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                 2.422766
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                          NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                            2.760965
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                         NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                        2.443083
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                    2.744113
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                       NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                  3.400124
# C3H4-P + HO2 <=> C3H3 + H2O2                                NaN
# C2H6 + HO2 <=> C2H5 + H2O2                             2.671291
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                        3.045143
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                           NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                    NaN
# CH3OH + HO2 <=> CH2OH + H2O2                           3.360106
# C4H10 + HO2 <=> SC4H9 + H2O2                           3.322825
# C2H5OH + HO2 <=> SC2H4OH + H2O2                        3.214453
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                           NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                       3.262334
# C3H8 + HO2 <=> IC3H7 + H2O2                            3.021795
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                          NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                           3.045143
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                           NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                       NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                  NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                        3.031766
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                       NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                        3.873507
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                           NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                           NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                          2.996727
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                           NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                           NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                           NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                           3.234516
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                    NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                         NaN
# CH2O + HO2 <=> HCO + H2O2                              3.882495
# HO2 + CH3OOH => H2O2 + CH3OO                                NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                    NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                          3.873507
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                      3.872062
# C2H5CHO + HO2 <=> C2H5CO + H2O2                        3.474943
#
#                                           GRI-17-species-mech  AramcoMech_1.3  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                      NaN        2.816148
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                        NaN             NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                           NaN        1.422766
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                          NaN        2.422766
# C4H10 + HO2 <=> PC4H9 + H2O2                              NaN        2.630424
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                         NaN             NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                        NaN        0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                        NaN        2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                          NaN             NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                             NaN        2.806515
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                         NaN             NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                        NaN             NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                        NaN        2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                       NaN        2.422584
# C2H5OH + HO2 <=> PC2H4OH + H2O2                           NaN        2.149583
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                    NaN        2.422766
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                        NaN             NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                               NaN        2.630424
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                         NaN             NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                       NaN        2.778970
# CH3OCHO + HO2 <=> CH3OCO + H2O2                           NaN        2.443083
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                       NaN        2.744113
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                          NaN             NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                     NaN             NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                     NaN        3.400124
# C3H4-P + HO2 <=> C3H3 + H2O2                              NaN             NaN
# C2H6 + HO2 <=> C2H5 + H2O2                                NaN        2.671291
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                           NaN        2.956467
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                         NaN             NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                  NaN             NaN
# CH3OH + HO2 <=> CH2OH + H2O2                              NaN        3.382143
# C4H10 + HO2 <=> SC4H9 + H2O2                              NaN        3.213307
# C2H5OH + HO2 <=> SC2H4OH + H2O2                           NaN        3.690421
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                         NaN             NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                          NaN        3.325807
# C3H8 + HO2 <=> IC3H7 + H2O2                               NaN        2.912277
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                        NaN             NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                              NaN        3.045143
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                         NaN             NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                     NaN             NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                NaN             NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                           NaN       -0.754556
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                     NaN             NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                           NaN        3.873507
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                         NaN        3.394941
# hoch2cho + ho2 <=> hoch2co + h2o2                         NaN             NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                             NaN        3.024477
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                         NaN             NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                         NaN        3.394941
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                         NaN        3.882562
# C3H6 + HO2 <=> C3H5-A + H2O2                              NaN        3.234516
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                  NaN             NaN
# CHD13 + HO2 <=> C6H7C + H2O2                              NaN             NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                       NaN             NaN
# CH2O + HO2 <=> HCO + H2O2                                 NaN        3.856517
# HO2 + CH3OOH => H2O2 + CH3OO                              NaN             NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                  NaN             NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                             NaN        3.873507
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                         NaN        3.872062
# C2H5CHO + HO2 <=> C2H5CO + H2O2                           NaN        3.474943
#
#                                           USC_Mech_ii  MB-Farooq  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2              NaN   2.816148
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                NaN        NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2              2.866062        NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                  NaN        NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                 2.723796        NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                 NaN        NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                NaN   0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                NaN   2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                  NaN        NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                2.739670        NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                 NaN        NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                NaN        NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                NaN   2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2               NaN   3.342434
# C2H5OH + HO2 <=> PC2H4OH + H2O2                   NaN   2.297818
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2            NaN   2.422766
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                NaN        NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                  2.723796   2.760430
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                 NaN        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2               NaN   2.906226
# CH3OCHO + HO2 <=> CH3OCO + H2O2                   NaN        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2               NaN   2.928828
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                  NaN        NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2             NaN        NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2             NaN   3.400124
# C3H4-P + HO2 <=> C3H3 + H2O2                      NaN        NaN
# C2H6 + HO2 <=> C2H5 + H2O2                        NaN   2.759014
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                   NaN        NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                 NaN        NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)          NaN        NaN
# CH3OH + HO2 <=> CH2OH + H2O2                      NaN   3.360106
# C4H10 + HO2 <=> SC4H9 + H2O2                 3.038790        NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                   NaN   3.214453
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                 NaN        NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                  NaN        NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                  2.744113   2.879938
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                NaN        NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                 2.563579        NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                 NaN        NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2             NaN        NaN
# C5H6 + HO2 <=> C5H5 + H2O2                   3.022159        NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                   NaN        NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2             NaN        NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                   NaN   3.871322
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                 NaN   3.394941
# hoch2cho + ho2 <=> hoch2co + h2o2                 NaN        NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                2.911578        NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                 NaN        NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                 NaN   3.394941
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                 NaN   3.474943
# C3H6 + HO2 <=> C3H5-A + H2O2                 2.742307   2.074935
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)          NaN        NaN
# CHD13 + HO2 <=> C6H7C + H2O2                      NaN        NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2               NaN        NaN
# CH2O + HO2 <=> HCO + H2O2                    4.251638   3.921922
# HO2 + CH3OOH => H2O2 + CH3OO                      NaN        NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)          NaN        NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                     NaN   3.871322
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                 NaN   3.872062
# C2H5CHO + HO2 <=> C2H5CO + H2O2                   NaN   3.596003
#
#                                           CombFlame2012/2028-Sarathy  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                        2.816148
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                          1.607895
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                             1.422766
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                            2.422766
# C4H10 + HO2 <=> PC4H9 + H2O2                                2.630424
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                           2.586227
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                          0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                          2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                            2.899888
# IC4H10 + HO2 <=> IC4H9 + H2O2                               2.806515
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                           2.100207
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                          1.651604
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                          2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                         2.422584
# C2H5OH + HO2 <=> PC2H4OH + H2O2                             2.960641
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                      2.422766
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                          2.220840
# C3H8 + HO2 <=> NC3H7 + H2O2                                 2.630424
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                           2.220840
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                         2.778970
# CH3OCHO + HO2 <=> CH3OCO + H2O2                             2.443083
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                         2.744113
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                 NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                       3.234516
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                       3.400124
# C3H4-P + HO2 <=> C3H3 + H2O2                                     NaN
# C2H6 + HO2 <=> C2H5 + H2O2                                  2.671291
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                             2.956467
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                           2.131148
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                         NaN
# CH3OH + HO2 <=> CH2OH + H2O2                                3.382143
# C4H10 + HO2 <=> SC4H9 + H2O2                                3.213307
# C2H5OH + HO2 <=> SC2H4OH + H2O2                             3.542967
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                           3.517136
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                            3.359244
# C3H8 + HO2 <=> IC3H7 + H2O2                                 2.912277
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                          3.429718
# IC4H8 + HO2 <=> IC4H7 + H2O2                                3.045143
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                       3.234516
# C5H6 + HO2 <=> C5H5 + H2O2                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                            -0.754556
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                       3.031766
# C2H3CHO + HO2 <=> C2H3CO + H2O2                             3.873507
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                           3.394941
# hoch2cho + ho2 <=> hoch2co + h2o2                           3.474943
# IC4H10 + HO2 <=> TC4H9 + H2O2                               3.024477
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                           3.394941
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                           3.882562
# C3H6 + HO2 <=> C3H5-A + H2O2                                3.234516
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                         NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                     NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                         3.474943
# CH2O + HO2 <=> HCO + H2O2                                   3.856517
# HO2 + CH3OOH => H2O2 + CH3OO                                     NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                         NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                               3.873507
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                           3.872062
# C2H5CHO + HO2 <=> C2H5CO + H2O2                             3.474943
#
#                                            Chernov  MB-Fisher  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2           NaN   2.816148
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2             NaN        NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                NaN        NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2               NaN        NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                   NaN        NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2              NaN        NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2             NaN   0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2             NaN   2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2               NaN        NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                  NaN        NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2              NaN        NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2             NaN        NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2             NaN   2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2            NaN   3.342434
# C2H5OH + HO2 <=> PC2H4OH + H2O2           2.432231   2.297818
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2         NaN   2.422766
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2             NaN        NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                    NaN   2.760430
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2              NaN        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2            NaN   2.906226
# CH3OCHO + HO2 <=> CH3OCO + H2O2                NaN        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2            NaN   2.928828
# IC4H7OH + HO2 <=> IC4H6OH + H2O2               NaN        NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2          NaN        NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2          NaN   3.400124
# C3H4-P + HO2 <=> C3H3 + H2O2                   NaN        NaN
# C2H6 + HO2 <=> C2H5 + H2O2                2.647563   2.759014
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                NaN        NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2              NaN        NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)       NaN        NaN
# CH3OH + HO2 <=> CH2OH + H2O2                   NaN   3.360106
# C4H10 + HO2 <=> SC4H9 + H2O2                   NaN        NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2           3.053280   3.214453
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2              NaN        NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2               NaN        NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                    NaN   2.879938
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2             NaN        NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                   NaN        NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ              NaN        NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2          NaN        NaN
# C5H6 + HO2 <=> C5H5 + H2O2                3.753025        NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                NaN        NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2          NaN        NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                NaN   3.871322
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2              NaN   3.394941
# hoch2cho + ho2 <=> hoch2co + h2o2              NaN        NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                  NaN        NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2              NaN        NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2              NaN   3.394941
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2              NaN   3.474943
# C3H6 + HO2 <=> C3H5-A + H2O2              2.742715   2.074935
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)       NaN        NaN
# CHD13 + HO2 <=> C6H7C + H2O2                   NaN        NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2            NaN        NaN
# CH2O + HO2 <=> HCO + H2O2                 3.620706   3.921922
# HO2 + CH3OOH => H2O2 + CH3OO                   NaN        NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)       NaN        NaN
# CH3CHO + HO2 <=> CH3CO + H2O2             3.872801   3.871322
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2              NaN   3.872062
# C2H5CHO + HO2 <=> C2H5CO + H2O2                NaN   3.596003
#
#                                           PCI2015/0153-Marshall  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                        NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                          NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                             NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                            NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                           NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                          NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                          NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                            NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                               NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                           NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                          NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                          NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                         NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                             NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                      NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                          NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                                 NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                         NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                             NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                         NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                       NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                       NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                                NaN
# C2H6 + HO2 <=> C2H5 + H2O2                                  NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                             NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                           NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                    NaN
# CH3OH + HO2 <=> CH2OH + H2O2                                NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                                NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                             NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                           NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                            NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                                 NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                          NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                           NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                       NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                  NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                             NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                       NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                             NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                           NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                           NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                               NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                           NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                           NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                           NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                                NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                    NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                         NaN
# CH2O + HO2 <=> HCO + H2O2                              3.882311
# HO2 + CH3OOH => H2O2 + CH3OO                                NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                    NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                               NaN
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                           NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                             NaN
#
#                                           PCI2015/0409-Zhang  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                     NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                       NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                          NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                         NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                             NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                        NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                       NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                       NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                            NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                        NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                          NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                   NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                       NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                              NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                      NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                          NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                      NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                         NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                    NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                    NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                             NaN
# C2H6 + HO2 <=> C2H5 + H2O2                               NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                          NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                        NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                 NaN
# CH3OH + HO2 <=> CH2OH + H2O2                             NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                             NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                          NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                        NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                         NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                              NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                       NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                             NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                        NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                    NaN
# C5H6 + HO2 <=> C5H5 + H2O2                               NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                          NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                    NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                          NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                        NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                            NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                        NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                        NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                        NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                             NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                 NaN
# CHD13 + HO2 <=> C6H7C + H2O2                             NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                      NaN
# CH2O + HO2 <=> HCO + H2O2                                NaN
# HO2 + CH3OOH => H2O2 + CH3OO                             NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                 NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                            NaN
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                        NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                          NaN
#
#                                                    ...            \
# Reaction                                           ...
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2               ...
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                 ...
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                    ...
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                   ...
# C4H10 + HO2 <=> PC4H9 + H2O2                       ...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                  ...
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                 ...
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                 ...
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                   ...
# IC4H10 + HO2 <=> IC4H9 + H2O2                      ...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                  ...
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                 ...
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                 ...
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                ...
# C2H5OH + HO2 <=> PC2H4OH + H2O2                    ...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2             ...
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                 ...
# C3H8 + HO2 <=> NC3H7 + H2O2                        ...
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                  ...
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                ...
# CH3OCHO + HO2 <=> CH3OCO + H2O2                    ...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                ...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                   ...
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2              ...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2              ...
# C3H4-P + HO2 <=> C3H3 + H2O2                       ...
# C2H6 + HO2 <=> C2H5 + H2O2                         ...
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                    ...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                  ...
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)           ...
# CH3OH + HO2 <=> CH2OH + H2O2                       ...
# C4H10 + HO2 <=> SC4H9 + H2O2                       ...
# C2H5OH + HO2 <=> SC2H4OH + H2O2                    ...
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                  ...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                   ...
# C3H8 + HO2 <=> IC3H7 + H2O2                        ...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                 ...
# IC4H8 + HO2 <=> IC4H7 + H2O2                       ...
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                  ...
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2              ...
# C5H6 + HO2 <=> C5H5 + H2O2                         ...
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                    ...
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2              ...
# C2H3CHO + HO2 <=> C2H3CO + H2O2                    ...
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                  ...
# hoch2cho + ho2 <=> hoch2co + h2o2                  ...
# IC4H10 + HO2 <=> TC4H9 + H2O2                      ...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                  ...
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                  ...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                  ...
# C3H6 + HO2 <=> C3H5-A + H2O2                       ...
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)           ...
# CHD13 + HO2 <=> C6H7C + H2O2                       ...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                ...
# CH2O + HO2 <=> HCO + H2O2                          ...
# HO2 + CH3OOH => H2O2 + CH3OO                       ...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)           ...
# CH3CHO + HO2 <=> CH3CO + H2O2                      ...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                  ...
# C2H5CHO + HO2 <=> C2H5CO + H2O2                    ...
#
#                                           PCI2017/051-Pelucchi  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                         NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                       1.924668
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                          2.234050
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                          NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                         NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                         NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                           NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                              NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                          NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                         NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                         NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                        NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                       1.924668
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                     NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                         NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                           3.164927
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                          NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                        NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                            NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                        NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                           NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                      NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                      NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                               NaN
# C2H6 + HO2 <=> C2H5 + H2O2                            2.442179
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                            NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                          NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                   NaN
# CH3OH + HO2 <=> CH2OH + H2O2                          3.663313
# C4H10 + HO2 <=> SC4H9 + H2O2                          2.783571
# C2H5OH + HO2 <=> SC2H4OH + H2O2                       2.548438
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                          NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                           NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                           3.277878
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                         NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                               NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                          NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                      NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                 NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                       3.144218
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                      NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                            NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                          NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                          NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                              NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                          NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                          NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                          NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                               NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                   NaN
# CHD13 + HO2 <=> C6H7C + H2O2                               NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                        NaN
# CH2O + HO2 <=> HCO + H2O2                             3.874915
# HO2 + CH3OOH => H2O2 + CH3OO                               NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                   NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                         3.602421
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                          NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                            NaN
#
#                                          PCI2017/038-Labbe-Zhao(30Torr-10Atm)  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                                      NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                        NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                                           NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                          NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                              NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                         NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                                        NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                                        NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                          NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                             NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                         NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                        NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                                        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                                       NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                                      2.593519
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                                    NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                        NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                                               NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                         NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                      2.371091
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                                       NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                          NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                     NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                                     NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                                              NaN
# C2H6 + HO2 <=> C2H5 + H2O2                                           2.203282
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                                           NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                         NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                  NaN
# CH3OH + HO2 <=> CH2OH + H2O2                                         3.360106
# C4H10 + HO2 <=> SC4H9 + H2O2                                              NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                                      3.214453
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                         NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                     3.695034
# C3H8 + HO2 <=> IC3H7 + H2O2                                               NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                        NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                                              NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                         NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                     NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                                NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                                           NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                     NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                                           NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                                         NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                         NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                                             NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                         NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                                         NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                                         NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                                              NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                  NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                              NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                       NaN
# CH2O + HO2 <=> HCO + H2O2                                            3.879095
# HO2 + CH3OOH => H2O2 + CH3OO                                              NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                  NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                                        3.890113
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                                         NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                                           NaN
#
#                                          PCI2017/111-Jin  PCI2017/037-Sakai  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                 NaN                NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                   NaN                NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                 2.866062           1.422766
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                     NaN           2.422766
# C4H10 + HO2 <=> PC4H9 + H2O2                    2.723796           2.630424
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                    NaN                NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                   NaN           0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2              2.759014           2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                     NaN                NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                        NaN           2.806515
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                    NaN                NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                   NaN                NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2              2.700300           2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                  NaN           2.422584
# C2H5OH + HO2 <=> PC2H4OH + H2O2                 2.149583           2.149583
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2               NaN                NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                   NaN                NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                     2.630424           2.630424
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                    NaN                NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                  NaN           2.778970
# CH3OCHO + HO2 <=> CH3OCO + H2O2                      NaN           2.443083
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                  NaN           2.744113
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                     NaN                NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                NaN                NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                NaN                NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                         NaN           3.384801
# C2H6 + HO2 <=> C2H5 + H2O2                           NaN           2.671291
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                 3.203123           2.956467
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                    NaN                NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)             NaN                NaN
# CH3OH + HO2 <=> CH2OH + H2O2                    3.382143           3.382143
# C4H10 + HO2 <=> SC4H9 + H2O2                    3.038790           3.213307
# C2H5OH + HO2 <=> SC2H4OH + H2O2                 3.690421           3.535519
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                    NaN                NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                     NaN           3.325807
# C3H8 + HO2 <=> IC3H7 + H2O2                     2.912277           2.912277
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                   NaN                NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                         NaN           3.045143
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                    NaN                NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                NaN                NaN
# C5H6 + HO2 <=> C5H5 + H2O2                           NaN                NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                 2.903925          -0.754556
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                NaN                NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                 3.474943           3.873507
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                    NaN           3.394941
# hoch2cho + ho2 <=> hoch2co + h2o2                    NaN                NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                        NaN           3.024477
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                    NaN                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                    NaN           3.394941
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                    NaN           3.882562
# C3H6 + HO2 <=> C3H5-A + H2O2                    2.742307           2.735463
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)             NaN                NaN
# CHD13 + HO2 <=> C6H7C + H2O2                         NaN                NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                  NaN                NaN
# ...
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                    1.422766
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                   2.422766
# C4H10 + HO2 <=> PC4H9 + H2O2                       2.630424
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                 0.402747
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                 2.759014
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                        NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                      2.806515
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                      NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                 2.700300
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                2.422584
# C2H5OH + HO2 <=> PC2H4OH + H2O2                    2.149583
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2             2.422766
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                      NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                        2.630424
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                2.778970
# CH3OCHO + HO2 <=> CH3OCO + H2O2                    2.443083
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                2.744113
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                        NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                   NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2              3.400124
# C3H4-P + HO2 <=> C3H3 + H2O2                            NaN
# C2H6 + HO2 <=> C2H5 + H2O2                         2.671291
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                    2.956467
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                       NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                NaN
# CH3OH + HO2 <=> CH2OH + H2O2                       3.382143
# C4H10 + HO2 <=> SC4H9 + H2O2                       3.213307
# C2H5OH + HO2 <=> SC2H4OH + H2O2                    3.690421
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                       NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                   3.325807
# C3H8 + HO2 <=> IC3H7 + H2O2                        2.912277
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                      NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                       3.045143
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                       NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                              NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                   -0.754556
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                   NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                    3.873507
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                  3.394941
# hoch2cho + ho2 <=> hoch2co + h2o2                       NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                      3.024477
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                       NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                  3.394941
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                  3.882562
# C3H6 + HO2 <=> C3H5-A + H2O2                       3.234516
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                NaN
# CHD13 + HO2 <=> C6H7C + H2O2                            NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                     NaN
# CH2O + HO2 <=> HCO + H2O2                          3.856517
# HO2 + CH3OOH => H2O2 + CH3OO                            NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                      3.873507
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                  3.872062
# C2H5CHO + HO2 <=> C2H5CO + H2O2                    3.474943
#
#                                           PCI2017/052-Stagni  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                     NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                       NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                          NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                         NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                             NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                        NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                       NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                  2.089974
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                            NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                        NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                     1.924668
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                   NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                       NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                         3.164927
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                      NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                          NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                      NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                         NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                    NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                    NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                        2.468267
# C2H6 + HO2 <=> C2H5 + H2O2                          2.442179
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                          NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                        NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                 NaN
# CH3OH + HO2 <=> CH2OH + H2O2                        3.663313
# C4H10 + HO2 <=> SC4H9 + H2O2                             NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                          NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                        NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                         NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                         3.277878
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                       NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                        3.223426
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                        NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                    NaN
# C5H6 + HO2 <=> C5H5 + H2O2                          3.133428
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                     3.144218
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                    NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                          NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                        NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                            NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                        NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                        NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                        NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                        2.922262
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                 NaN
# CHD13 + HO2 <=> C6H7C + H2O2                             NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                      NaN
# CH2O + HO2 <=> HCO + H2O2                           3.874915
# HO2 + CH3OOH => H2O2 + CH3OO                        2.652639
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                 NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                            NaN
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                        NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                          NaN
#
#                                           PCI2017/047-Rodriguez  \
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                        NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                          NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                             NaN
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                            NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                            3.04843
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                           NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                          NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                          NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                            NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                               NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                           NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                          NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                          NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                         NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                             NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                      NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                          NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                             2.59668
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                         NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                             NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                         NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                       NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                       NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                                NaN
# C2H6 + HO2 <=> C2H5 + H2O2                              2.65562
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                         2.89622
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                           NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                    NaN
# CH3OH + HO2 <=> CH2OH + H2O2                             2.2286
# C4H10 + HO2 <=> SC4H9 + H2O2                                NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                         3.58576
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                           NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                            NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                                 NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                          NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                           NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                       NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                  NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                          2.9557
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                       NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                             NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                           NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                           NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                               NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                           NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                           NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                           NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                            2.74449
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                    NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                         NaN
# CH2O + HO2 <=> HCO + H2O2                               3.63603
# HO2 + CH3OOH => H2O2 + CH3OO                                NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                    NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                           3.81455
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                           NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                         3.81455
#
#                                           AutoTST-OOHabstraction
# Reaction
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                    0.273268
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                      0.496368
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                         0.597343
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                        0.738523
# C4H10 + HO2 <=> PC4H9 + H2O2                            0.900685
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                       0.953664
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                      0.973664
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                      0.977516
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                        0.980454
# IC4H10 + HO2 <=> IC4H9 + H2O2                           0.992867
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                       1.050164
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                      1.068791
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                      1.098694
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                     1.182977
# C2H5OH + HO2 <=> PC2H4OH + H2O2                         1.220435
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                  1.232200
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                      1.239004
# C3H8 + HO2 <=> NC3H7 + H2O2                             1.431323
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                       1.452121
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                     1.464148
# CH3OCHO + HO2 <=> CH3OCO + H2O2                         1.483578
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                     1.509777
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                        1.559070
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                   1.704032
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                   1.781042
# C3H4-P + HO2 <=> C3H3 + H2O2                            1.841442
# C2H6 + HO2 <=> C2H5 + H2O2                              1.889037
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                         1.897644
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                       1.948314
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                1.997851
# CH3OH + HO2 <=> CH2OH + H2O2                            2.049792
# C4H10 + HO2 <=> SC4H9 + H2O2                            2.080432
# C2H5OH + HO2 <=> SC2H4OH + H2O2                         2.108171
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                       2.119074
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                        2.130294
# C3H8 + HO2 <=> IC3H7 + H2O2                             2.222221
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                      2.224434
# IC4H8 + HO2 <=> IC4H7 + H2O2                            2.249487
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                       2.255284
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                   2.263777
# C5H6 + HO2 <=> C5H5 + H2O2                              2.284634
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                         2.455105
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                   2.457353
# C2H3CHO + HO2 <=> C2H3CO + H2O2                         2.541386
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                       2.595245
# hoch2cho + ho2 <=> hoch2co + h2o2                       2.626006
# IC4H10 + HO2 <=> TC4H9 + H2O2                           2.670441
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                       2.715961
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                       2.733183
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                       2.819382
# C3H6 + HO2 <=> C3H5-A + H2O2                            2.892786
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                2.969001
# CHD13 + HO2 <=> C6H7C + H2O2                            2.969564
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                     3.050256
# CH2O + HO2 <=> HCO + H2O2                               3.125098
# HO2 + CH3OOH => H2O2 + CH3OO                            3.187324
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                3.306507
# CH3CHO + HO2 <=> CH3CO + H2O2                           3.324195
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                       3.422479
# C2H5CHO + HO2 <=> C2H5CO + H2O2                         3.792408
#
# [60 rows x 74 columns]

# %%
# %cd plotOutputResults
# Out:
# /Users/nathan/Code/OOHAbstraction_Testing/plotOutputResults

# %%
boxPlot = kinSheet.transpose().plot.box(figsize=(10,10), grid=True, rot=90)
boxPlot.plot(range(1,kinSheet.transpose().shape[1]+1),kinSheet.transpose().loc['AutoTST-OOHabstraction'].values, marker='o', color='k', linestyle='')
boxPlot.set_ylabel('$log_{10}(k)$', fontsize=20)
boxPlot.set_xlabel('Reaction', fontsize=20)

# %% [markdown]
# ## Making the parity plot

# %%
for j in kinSheet.index:
    mean = kinSheet.loc[j].mean(axis=0) + 6
    autoTST = kinSheet['AutoTST-OOHabstraction'].loc[j] + 6
    x_list = []
    y_list = []
    for i in list(kinSheet):
        if i != "AutoTST-OOHabstraction" and pd.isnull(kinSheet[i].loc[j]) == False:
            x_list.append(kinSheet[i].loc[j] + 6)
            y_list.append(autoTST)
            
        
    plt.plot(x_list, y_list, '-b') # Line for the range for each AutoTST point
    plt.plot(x_list, y_list, '|b') # Tick marks for each point
    plt.plot(mean, autoTST, '.k') # Dots for each average data point
    plt.plot(range(-2, 20), range(-2, 20), '-g') # Parity Line
    plt.plot(range(-3, 19), range(-2, 20), ':g') # 1 order of magnitude
    plt.plot(range(-1, 21), range(-2, 20), ':g') # 1 order of magnitude
    plt.ylim([6,11])
    plt.xlim([6,11])
    plt.xlabel('$log_{10}k (T=1000 K, P=100 bar) [cm^3 / (mole \cdot s)]$ by Imported Kinetics', fontsize=10)
    plt.ylabel('$log_{10}k (T=1000 K, P=100 bar) [cm^3 / (mole \cdot s)]$ by AutoTST', fontsize=10)
    plt.tick_params(axis='x', labelsize=8)
    plt.tick_params(axis='y', labelsize=8)

plt.savefig('parityPlot.pdf')

# %% [markdown]
# ## Making the Arrhenius plots for each reaction

# %%
rxnList = expressionSheet['AutoTST-OOHabstraction'].dropna(axis=0).index.values
expSheet = expressionSheet.ix[rxnList].sort(columns='AutoTST-OOHabstraction').set_index('Reaction')
expSheet
# Out:
# /Users/nathan/anaconda/envs/rmg_env/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                                       PCI2013/353-Malewicki  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2          'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2           'Arrhenius(A=(2380,'cm^3/(mol*s)'), n=2.55, Ea...
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2         'Arrhenius(A=(3e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(58800,'cm^3/(mol*s)'), n=2.5, Ea...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2        'Arrhenius(A=(27400,'cm^3/(mol*s)'), n=2.55, E...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(12300,'cm^3/(mol*s)'), n=2.55, E...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(81000,'cm^3/(mol*s)'), n=2.5, Ea...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(8200,'cm^3/(mol*s)'), n=2.55, Ea...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2       'Arrhenius(A=(9640,'cm^3/(mol*s)'), n=2.6, Ea=...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2    'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2           'Arrhenius(A=(4820,'cm^3/(mol*s)'), n=2.6, Ea=...
# IC4H10 + HO2 <=> IC4H9 + H2O2             'Arrhenius(A=(121500,'cm^3/(mol*s)'), n=2.5, E...
# C4H10 + HO2 <=> PC4H9 + H2O2              'Arrhenius(A=(81000,'cm^3/(mol*s)'), n=2.5, Ea...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(34.6,'cm^3/(mol*s)'), n=3.61, Ea...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2          'Arrhenius(A=(1.344e+13,'cm^3/(mol*s)'), n=0, ...
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2              'Arrhenius(A=(117600,'cm^3/(mol*s)'), n=2.5, E...
# IC4H10 + HO2 <=> TC4H9 + H2O2             'Arrhenius(A=(15000,'cm^3/(mol*s)'), n=2.5, Ea...
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                                                     NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2        'Arrhenius(A=(1.13e+13,'cm^3/(mol*s)'), n=0, E...
# IC4H8 + HO2 <=> IC4H7 + H2O2              'Arrhenius(A=(19280,'cm^3/(mol*s)'), n=2.6, Ea...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2     'Arrhenius(A=(2e+11,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=2.5, Ea...
# C2H3CHO + HO2 <=> C2H3CO + H2O2           'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                                                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                                                     NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(19280,'cm^3/(mol*s)'), n=2.6, Ea...
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                                                       NaN
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                                              NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(4820,'cm^3/(mol*s)'), n=2.55, Ea...
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                                                       NaN
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2      'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(3.98e+13,'cm^3/(mol*s)'), n=0, E...
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                          GRI-17-species-mech  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                         NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                        NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                       NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                          NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                            NaN
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                        NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                          NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                              NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                        NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                       NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                          NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                      NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                              NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                          NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                      NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                   NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                        NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                          NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                            NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                             NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                        NaN
# C2H6 + HO2 <=> C2H5 + H2O2                               NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                         NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                        NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                       NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                             NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                            NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                      NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                         NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                        NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                       NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                             NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                    NaN
# C3H6 + HO2 <=> C3H5-A + H2O2                             NaN
# C2H3CHO + HO2 <=> C2H3CO + H2O2                          NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                        NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                 NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                        NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                      NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                          NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                    NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                 NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                        NaN
# HO2 + CH3OOH => H2O2 + CH3OO                             NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                    NaN
# C5H6 + HO2 <=> C5H5 + H2O2                               NaN
# CHD13 + HO2 <=> C6H7C + H2O2                             NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                    NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                       NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                 NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                        NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                          NaN
# CH2O + HO2 <=> HCO + H2O2                                NaN
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                        NaN
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                     NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                         NaN
# CH3OH + HO2 <=> CH2OH + H2O2                             NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                             NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                       NaN
#
#                                                                              AramcoMech_1.3  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2          'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2           'Arrhenius(A=(2380,'cm^3/(mol*s)'), n=2.55, Ea...
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2         'Arrhenius(A=(3e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(63.2,'cm^3/(mol*s)'), n=3.37, Ea...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2        'Arrhenius(A=(27400,'cm^3/(mol*s)'), n=2.55, E...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(0.03986,'cm^3/(mol*s)'), n=4.3, ...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(40.8,'cm^3/(mol*s)'), n=3.59, Ea...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(3.5e-05,'cm^3/(mol*s)'), n=5.26,...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2       'Arrhenius(A=(9640,'cm^3/(mol*s)'), n=2.6, Ea=...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2    'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2           'Arrhenius(A=(4820,'cm^3/(mol*s)'), n=2.6, Ea=...
# IC4H10 + HO2 <=> IC4H9 + H2O2             'Arrhenius(A=(61.2,'cm^3/(mol*s)'), n=3.59, Ea...
# C4H10 + HO2 <=> PC4H9 + H2O2              'Arrhenius(A=(40.8,'cm^3/(mol*s)'), n=3.59, Ea...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(34.6,'cm^3/(mol*s)'), n=3.61, Ea...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2          'Arrhenius(A=(867,'cm^3/(mol*s)'), n=3.01, Ea=...
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2              'Arrhenius(A=(126.4,'cm^3/(mol*s)'), n=3.37, E...
# IC4H10 + HO2 <=> TC4H9 + H2O2             'Arrhenius(A=(433.2,'cm^3/(mol*s)'), n=3.01, E...
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2       'Arrhenius(A=(23790,'cm^3/(mol*s)'), n=2.55, E...
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2        'Arrhenius(A=(1.13e+13,'cm^3/(mol*s)'), n=0, E...
# IC4H8 + HO2 <=> IC4H7 + H2O2              'Arrhenius(A=(19280,'cm^3/(mol*s)'), n=2.6, Ea...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2     'Arrhenius(A=(2e+11,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=2.5, Ea...
# C2H3CHO + HO2 <=> C2H3CO + H2O2           'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2       'Arrhenius(A=(3.44e+12,'cm^3/(mol*s)'), n=0.05...
# C4H8-2 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(59400,'cm^3/(mol*s)'), n=2.57, E...
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                                              NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=0.7, Ea...
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(18800,'cm^3/(mol*s)'), n=2.7, Ea...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2         'Arrhenius(A=(40900,'cm^3/(mol*s)'), n=2.5, Ea...
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2      'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(10800,'cm^3/(mol*s)'), n=2.55, E...
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                                 USC_Mech_ii  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2           'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# CH3CHO + HO2 <=> CH3CO + H2O2                                                           NaN
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                                                       NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                                                         NaN
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(9640,'cm^3/(mol*s)'), n=2.6, Ea=...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                                                      NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                                                         NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(47600,'cm^3/(mol*s)'), n=2.55, E...
# C2H5OH + HO2 <=> SC2H4OH + H2O2                                                         NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                                                     NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                                                  NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2             'Arrhenius(A=(30000,'cm^3/(mol*s)'), n=2.55, E...
# C4H10 + HO2 <=> PC4H9 + H2O2              'Arrhenius(A=(47600,'cm^3/(mol*s)'), n=2.55, E...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                                                              NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2              'Arrhenius(A=(19000,'cm^3/(mol*s)'), n=2.6, Ea...
# IC4H10 + HO2 <=> TC4H9 + H2O2             'Arrhenius(A=(3600,'cm^3/(mol*s)'), n=2.55, Ea...
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                                                     NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                                                      NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2              'Arrhenius(A=(20000,'cm^3/(mol*s)'), n=2.55, E...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                                                   NaN
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(9600,'cm^3/(mol*s)'), n=2.6, Ea=...
# C2H3CHO + HO2 <=> C2H3CO + H2O2                                                         NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                                                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                                                     NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                                                       NaN
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                'Arrhenius(A=(11000,'cm^3/(mol*s)'), n=2.6, Ea...
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                                                      NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                                                       NaN
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                                                    NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2                                                            NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                                   MB-Farooq  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                                                         NaN
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2         'Arrhenius(A=(3e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(5.6e+12,'cm^3/(mol*s)'), n=0, Ea...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2        'Arrhenius(A=(27400,'cm^3/(mol*s)'), n=2.55, E...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(12300,'cm^3/(mol*s)'), n=2.55, E...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(1.68e+13,'cm^3/(mol*s)'), n=0, E...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(8200,'cm^3/(mol*s)'), n=2.55, Ea...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2       'Arrhenius(A=(14750,'cm^3/(mol*s)'), n=2.6, Ea...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2    'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                                                            NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                                                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2       'Arrhenius(A=(0.903,'cm^3/(mol*s)'), n=3.65, E...
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2        'Arrhenius(A=(1.13e+13,'cm^3/(mol*s)'), n=0, E...
# IC4H8 + HO2 <=> IC4H7 + H2O2                                                            NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2     'Arrhenius(A=(2e+11,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(1.5e+11,'cm^3/(mol*s)'), n=0, Ea...
# C2H3CHO + HO2 <=> C2H3CO + H2O2           'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2       'Arrhenius(A=(3610,'cm^3/(mol*s)'), n=2.55, Ea...
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                                              NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(0.00582,'cm^3/(mol*s)'), n=4.53,...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2         'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2      'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(3.98e+13,'cm^3/(mol*s)'), n=0, E...
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                  CombFlame2012/2028-Sarathy  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2          'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2         'Arrhenius(A=(3.5e-05,'cm^3/(mol*s)'), n=5.26,...
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2        'Arrhenius(A=(0.00751,'cm^3/(mol*s)'), n=4.52,...
# C4H8-1 + HO2 <=> C4H71-4 + H2O2           'Arrhenius(A=(2380,'cm^3/(mol*s)'), n=2.55, Ea...
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2         'Arrhenius(A=(3e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(63.2,'cm^3/(mol*s)'), n=3.37, Ea...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2         'Arrhenius(A=(0.000276,'cm^3/(mol*s)'), n=4.76...
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2        'Arrhenius(A=(27400,'cm^3/(mol*s)'), n=2.55, E...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2        'Arrhenius(A=(3.5e-05,'cm^3/(mol*s)'), n=5.26,...
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(0.00904,'cm^3/(mol*s)'), n=4.54,...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2       'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(40.8,'cm^3/(mol*s)'), n=3.59, Ea...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(0.028,'cm^3/(mol*s)'), n=4.32, E...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2       'Arrhenius(A=(9640,'cm^3/(mol*s)'), n=2.6, Ea=...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2    'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2         'Arrhenius(A=(0.088,'cm^3/(mol*s)'), n=4.31, E...
# CH3OCHO + HO2 <=> CH3OCO + H2O2           'Arrhenius(A=(4820,'cm^3/(mol*s)'), n=2.6, Ea=...
# IC4H10 + HO2 <=> IC4H9 + H2O2             'Arrhenius(A=(61.2,'cm^3/(mol*s)'), n=3.59, Ea...
# C4H10 + HO2 <=> PC4H9 + H2O2              'Arrhenius(A=(40.8,'cm^3/(mol*s)'), n=3.59, Ea...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2         'Arrhenius(A=(0.0113,'cm^3/(mol*s)'), n=4.52, ...
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(34.6,'cm^3/(mol*s)'), n=3.61, Ea...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2          'Arrhenius(A=(1.68e+13,'cm^3/(mol*s)'), n=0, E...
# hoch2cho + ho2 <=> hoch2co + h2o2         'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2        'Arrhenius(A=(0.000414,'cm^3/(mol*s)'), n=4.76...
# C4H10 + HO2 <=> SC4H9 + H2O2              'Arrhenius(A=(126.4,'cm^3/(mol*s)'), n=3.37, E...
# IC4H10 + HO2 <=> TC4H9 + H2O2             'Arrhenius(A=(433.2,'cm^3/(mol*s)'), n=3.01, E...
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2       'Arrhenius(A=(23790,'cm^3/(mol*s)'), n=2.55, E...
# tc4h9oh + ho2 <=> tc4h8oh + h2o2          'Arrhenius(A=(71400,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2         'Arrhenius(A=(0.00751,'cm^3/(mol*s)'), n=4.52,...
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2        'Arrhenius(A=(1.13e+13,'cm^3/(mol*s)'), n=0, E...
# IC4H8 + HO2 <=> IC4H7 + H2O2              'Arrhenius(A=(19280,'cm^3/(mol*s)'), n=2.6, Ea...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2     'Arrhenius(A=(2e+11,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=2.5, Ea...
# C2H3CHO + HO2 <=> C2H3CO + H2O2           'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2       'Arrhenius(A=(3.44e+12,'cm^3/(mol*s)'), n=0.05...
# C4H8-2 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(59400,'cm^3/(mol*s)'), n=2.57, E...
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2     'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=2.5, Ea...
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2     'Arrhenius(A=(4820,'cm^3/(mol*s)'), n=2.55, Ea...
# C5H6 + HO2 <=> C5H5 + H2O2                                                              NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2     'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=2.5, Ea...
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(27000,'cm^3/(mol*s)'), n=0.7, Ea...
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(18800,'cm^3/(mol*s)'), n=2.7, Ea...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2         'Arrhenius(A=(40900,'cm^3/(mol*s)'), n=2.5, Ea...
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2      'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(10800,'cm^3/(mol*s)'), n=2.55, E...
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2        'Arrhenius(A=(0.000414,'cm^3/(mol*s)'), n=4.76...
#
#                                                                                     Chernov  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                                                         NaN
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                                                       NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                                                         NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                                                             NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                                                      NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(24300,'cm^3/(mol*s)'), n=2.5, Ea...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                                                             NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(8200,'cm^3/(mol*s)'), n=2.5, Ea=...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                                                     NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                                                  NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(1.32e+13,'cm^3/(mol*s)'), n=0, E...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                                                            NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                                                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                                                     NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                                                      NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                                                            NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                                                   NaN
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(9640,'cm^3/(mol*s)'), n=2.6, Ea=...
# C2H3CHO + HO2 <=> C2H3CO + H2O2                                                         NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                                                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                                                     NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                                                       NaN
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                'Arrhenius(A=(2e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                                                      NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                                                       NaN
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                                                    NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2                                                            NaN
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                                   MB-Fisher  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                                                         NaN
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2         'Arrhenius(A=(3e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(5.6e+12,'cm^3/(mol*s)'), n=0, Ea...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2        'Arrhenius(A=(27400,'cm^3/(mol*s)'), n=2.55, E...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(12300,'cm^3/(mol*s)'), n=2.55, E...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(1.68e+13,'cm^3/(mol*s)'), n=0, E...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(8200,'cm^3/(mol*s)'), n=2.55, Ea...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2       'Arrhenius(A=(14750,'cm^3/(mol*s)'), n=2.6, Ea...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2    'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                                                            NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                                                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2       'Arrhenius(A=(0.903,'cm^3/(mol*s)'), n=3.65, E...
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2        'Arrhenius(A=(1.13e+13,'cm^3/(mol*s)'), n=0, E...
# IC4H8 + HO2 <=> IC4H7 + H2O2                                                            NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2     'Arrhenius(A=(2e+11,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(1.5e+11,'cm^3/(mol*s)'), n=0, Ea...
# C2H3CHO + HO2 <=> C2H3CO + H2O2           'Arrhenius(A=(3.01e+12,'cm^3/(mol*s)'), n=0, E...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2       'Arrhenius(A=(3610,'cm^3/(mol*s)'), n=2.55, Ea...
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2         'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                                              NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(0.00582,'cm^3/(mol*s)'), n=4.53,...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2         'Arrhenius(A=(2.8e+12,'cm^3/(mol*s)'), n=0, Ea...
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2      'Arrhenius(A=(23800,'cm^3/(mol*s)'), n=2.55, E...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(3.98e+13,'cm^3/(mol*s)'), n=0, E...
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                       PCI2015/0153-Marshall  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                                                         NaN
# CH3CHO + HO2 <=> CH3CO + H2O2                                                           NaN
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                                                       NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2                                                         NaN
# C3H8 + HO2 <=> IC3H7 + H2O2                                                             NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                                                      NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                                                         NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2                                                             NaN
# C2H5OH + HO2 <=> SC2H4OH + H2O2                                                         NaN
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                                                     NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                                                  NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                                                              NaN
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                                                  NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(484900,'cm^3/(mol*s)'), n=2, Ea=...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                                                            NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                                                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                                                     NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                                                      NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2              'Arrhenius(A=(323300,'cm^3/(mol*s)'), n=2, Ea=...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                                                   NaN
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(161600,'cm^3/(mol*s)'), n=2, Ea=...
# C2H3CHO + HO2 <=> C2H3CO + H2O2                                                         NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                                                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                                                     NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2                                                         NaN
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                                                       NaN
# HO2 + CH3OOH => H2O2 + CH3OO              'Arrhenius(A=(107800,'cm^3/(mol*s)'), n=2, Ea=...
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                'Arrhenius(A=(538800,'cm^3/(mol*s)'), n=2, Ea=...
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(215500,'cm^3/(mol*s)'), n=2, Ea=...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(269400,'cm^3/(mol*s)'), n=2, Ea=...
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(5.2e+12,'cm^3/(mol*s)'), n=0, Ea...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                                                       NaN
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                                                    NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(8e+13,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H4-P + HO2 <=> C3H3 + H2O2              'Arrhenius(A=(3.233e+06,'cm^3/(mol*s)'), n=2, ...
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                       PCI2017/047-Rodriguez  \
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2                                                       NaN
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2                                                      NaN
# C4H8-1 + HO2 <=> C4H71-4 + H2O2                                                         NaN
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2                                                       NaN
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(1e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# C3H8 + HO2 <=> IC3H7 + H2O2                                                             NaN
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2                                                       NaN
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2                                                      NaN
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2                                                      NaN
# C2H5OH + HO2 <=> PC2H4OH + H2O2                                                         NaN
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2                                                     NaN
# C3H8 + HO2 <=> NC3H7 + H2O2               'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+1...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(2e+13,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2                                                     NaN
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2                                                  NaN
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2                                                       NaN
# CH3OCHO + HO2 <=> CH3OCO + H2O2                                                         NaN
# IC4H10 + HO2 <=> IC4H9 + H2O2                                                           NaN
# C4H10 + HO2 <=> PC4H9 + H2O2              'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+1...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2                                                       NaN
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(1.3e+13,'cm^3/(mol*s)'), n=0, Ea...
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2                                                        NaN
# hoch2cho + ho2 <=> hoch2co + h2o2                                                       NaN
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2                                                      NaN
# C4H10 + HO2 <=> SC4H9 + H2O2                                                            NaN
# IC4H10 + HO2 <=> TC4H9 + H2O2                                                           NaN
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2                                                     NaN
# tc4h9oh + ho2 <=> tc4h8oh + h2o2                                                        NaN
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2                                                       NaN
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2                                                      NaN
# IC4H8 + HO2 <=> IC4H7 + H2O2                                                            NaN
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2                                                   NaN
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(9600,'cm^3/(mol*s)'), n=2.6, Ea=...
# C2H3CHO + HO2 <=> C2H3CO + H2O2                                                         NaN
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2                                                       NaN
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)                                                NaN
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2                                                       NaN
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2                                                     NaN
# C4H8-2 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(6400,'cm^3/(mol*s)'), n=2.6, Ea=...
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)                                                NaN
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2                                                       NaN
# HO2 + CH3OOH => H2O2 + CH3OO                                                            NaN
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2                                                   NaN
# C5H6 + HO2 <=> C5H5 + H2O2                                                              NaN
# CHD13 + HO2 <=> C6H7C + H2O2                                                            NaN
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2                                                   NaN
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2                                                      NaN
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)                                                NaN
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ                                                       NaN
# C4H8-1 + HO2 <=> C4H71-3 + H2O2           'MultiArrhenius(arrhenius=[Arrhenius(A=(6400,'...
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(3e+12,'cm^3/(mol*s)'), n=0, Ea=(...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2                                                       NaN
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2                                                    NaN
# IC4H7OH + HO2 <=> IC4H6OH + H2O2                                                        NaN
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(9.6e+10,'cm^3/(mol*s)'), n=0, Ea...
# C3H4-P + HO2 <=> C3H3 + H2O2                                                            NaN
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2                                                      NaN
#
#                                                                      AutoTST-OOHabstraction
# Reaction
# CH3OCHO + HO2 <=> CH2OCHO + H2O2          'Arrhenius(A=(0.000104186,'cm^3/(mol*s)'), n=4...
# nc4h9oh + ho2 <=> c4h8oh-1 + h2o2         'Arrhenius(A=(0.000166121,'cm^3/(mol*s)'), n=4...
# sc4h9oh + ho2 <=> sc4h8oh-2 + h2o2        'Arrhenius(A=(0.000181889,'cm^3/(mol*s)'), n=4...
# C4H8-1 + HO2 <=> C4H71-4 + H2O2           'Arrhenius(A=(0.000220412,'cm^3/(mol*s)'), n=4...
# CH3CHO + HO2 <=> CH3CO + H2O2             'Arrhenius(A=(0.000274848,'cm^3/(mol*s)'), n=4...
# IC3H7CHO + HO2 <=> IC3H7CO + H2O2         'Arrhenius(A=(0.000281069,'cm^3/(mol*s)'), n=4...
# C2H5CHO + HO2 <=> C2H5CO + H2O2           'Arrhenius(A=(0.000293965,'cm^3/(mol*s)'), n=4...
# C3H8 + HO2 <=> IC3H7 + H2O2               'Arrhenius(A=(0.000337358,'cm^3/(mol*s)'), n=4...
# nc4h9oh + ho2 <=> c4h8oh-3 + h2o2         'Arrhenius(A=(0.000375686,'cm^3/(mol*s)'), n=4...
# IC3H7CHO + HO2 <=> IC3H6CHO + H2O2        'Arrhenius(A=(0.000383212,'cm^3/(mol*s)'), n=4...
# ic4h9oh + ho2 <=> ic4h8oh-1 + h2o2        'Arrhenius(A=(0.000391488,'cm^3/(mol*s)'), n=4...
# C2H5OH + HO2 <=> PC2H4OH + H2O2           'Arrhenius(A=(0.000409287,'cm^3/(mol*s)'), n=4...
# hoc2h4cho + ho2 <=> hoc2h4co + h2o2       'Arrhenius(A=(0.000423229,'cm^3/(mol*s)'), n=4...
# C3H8 + HO2 <=> NC3H7 + H2O2               'Arrhenius(A=(0.000510827,'cm^3/(mol*s)'), n=4...
# C2H5OH + HO2 <=> SC2H4OH + H2O2           'Arrhenius(A=(0.000564314,'cm^3/(mol*s)'), n=4...
# NC3H7CHO + HO2 <=> C3H6CHO-2 + H2O2       'Arrhenius(A=(0.000583326,'cm^3/(mol*s)'), n=4...
# C2H5COCH3 + HO2 <=> CH2CH2COCH3 + H2O2    'Arrhenius(A=(0.000631728,'cm^3/(mol*s)'), n=4...
# nc4h9oh + ho2 <=> c4h8oh-4 + h2o2         'Arrhenius(A=(0.000740853,'cm^3/(mol*s)'), n=4...
# CH3OCHO + HO2 <=> CH3OCO + H2O2           'Arrhenius(A=(0.000827612,'cm^3/(mol*s)'), n=4...
# IC4H10 + HO2 <=> IC4H9 + H2O2             'Arrhenius(A=(0.000832921,'cm^3/(mol*s)'), n=4...
# C4H10 + HO2 <=> PC4H9 + H2O2              'Arrhenius(A=(0.000948686,'cm^3/(mol*s)'), n=4...
# sc4h9oh + ho2 <=> sc4h8ohm + h2o2         'Arrhenius(A=(0.00102796,'cm^3/(mol*s)'), n=4....
# C2H6 + HO2 <=> C2H5 + H2O2                'Arrhenius(A=(0.00107611,'cm^3/(mol*s)'), n=4....
# CH3OCH3 + HO2 <=> CH3OCH2 + H2O2          'Arrhenius(A=(0.00107875,'cm^3/(mol*s)'), n=4....
# hoch2cho + ho2 <=> hoch2co + h2o2         'Arrhenius(A=(0.00108079,'cm^3/(mol*s)'), n=4....
# ic4h9oh + ho2 <=> ic4h8oh-3 + h2o2        'Arrhenius(A=(0.001262,'cm^3/(mol*s)'), n=4.35...
# C4H10 + HO2 <=> SC4H9 + H2O2              'Arrhenius(A=(0.00210652,'cm^3/(mol*s)'), n=4....
# IC4H10 + HO2 <=> TC4H9 + H2O2             'Arrhenius(A=(0.00381462,'cm^3/(mol*s)'), n=4....
# NC3H7CHO + HO2 <=> C3H6CHO-1 + H2O2       'Arrhenius(A=(0.0059468,'cm^3/(mol*s)'), n=4.1...
# tc4h9oh + ho2 <=> tc4h8oh + h2o2          'Arrhenius(A=(0.0142764,'cm^3/(mol*s)'), n=4.0...
# nc4h9oh + ho2 <=> c4h8oh-2 + h2o2         'Arrhenius(A=(0.0157366,'cm^3/(mol*s)'), n=3.8...
# C2H4O1-2 + HO2 <=> C2H3O1-2 + H2O2        'Arrhenius(A=(0.102149,'cm^3/(mol*s)'), n=3.87...
# IC4H8 + HO2 <=> IC4H7 + H2O2              'Arrhenius(A=(1.05586e-07,'cm^3/(mol*s)'), n=5...
# C2H5COCH3 + HO2 <=> CH3CHCOCH3 + H2O2     'Arrhenius(A=(1.10146e-06,'cm^3/(mol*s)'), n=5...
# C3H6 + HO2 <=> C3H5-A + H2O2              'Arrhenius(A=(1.23038e-10,'cm^3/(mol*s)'), n=6...
# C2H3CHO + HO2 <=> C2H3CO + H2O2           'Arrhenius(A=(1.37519e-05,'cm^3/(mol*s)'), n=5...
# C5H81-4 + HO2 <=> C*CC*CCJ + H2O2         'Arrhenius(A=(1.46901e-07,'cm^3/(mol*s)'), n=5...
# C6H8(19) + HO2(2) <=> C6H7(20) + H2O2(4)  'Arrhenius(A=(1.56034e-10,'cm^3/(mol*s)'), n=6...
# SC3H5CHO + HO2 <=> SC3H5CO + H2O2         'Arrhenius(A=(1.63673e-05,'cm^3/(mol*s)'), n=4...
# NC3H7CHO + HO2 <=> C3H6CHO-3 + H2O2       'Arrhenius(A=(1.70895e-08,'cm^3/(mol*s)'), n=5...
# C4H8-2 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(1.85695e-08,'cm^3/(mol*s)'), n=5...
# c4h7oh1-2 + ho2 <=> c4h6oh1-32 + h2o2     'Arrhenius(A=(1.86399e-07,'cm^3/(mol*s)'), n=5...
# C6H8(54) + HO2(2) <=> C6H7(55) + H2O2(4)  'Arrhenius(A=(2.01875e-07,'cm^3/(mol*s)'), n=5...
# IC3H5CHO + HO2 <=> IC3H5CO + H2O2         'Arrhenius(A=(2.22601e-05,'cm^3/(mol*s)'), n=4...
# HO2 + CH3OOH => H2O2 + CH3OO              'Arrhenius(A=(2.25347e-05,'cm^3/(mol*s)'), n=4...
# c4h7oh1-1 + ho2 <=> c4h6oh1-13 + h2o2     'Arrhenius(A=(2.56079e-07,'cm^3/(mol*s)'), n=5...
# C5H6 + HO2 <=> C5H5 + H2O2                'Arrhenius(A=(2.75415e-08,'cm^3/(mol*s)'), n=5...
# CHD13 + HO2 <=> C6H7C + H2O2              'Arrhenius(A=(2.81635e-06,'cm^3/(mol*s)'), n=5...
# c4h7oh2-2 + ho2 <=> c4h6oh1-32 + h2o2     'Arrhenius(A=(3.05514e-08,'cm^3/(mol*s)'), n=5...
# CH3COCH3 + HO2 <=> CH3COCH2 + H2O2        'Arrhenius(A=(3.89078e-06,'cm^3/(mol*s)'), n=4...
# C6H8(19) + HO2(2) <=> C6H7(81) + H2O2(4)  'Arrhenius(A=(3.96701e-10,'cm^3/(mol*s)'), n=6...
# HO2 + C*CC*CC <=> H2O2 + C*CC*CCJ         'Arrhenius(A=(4.0144e-10,'cm^3/(mol*s)'), n=6....
# C4H8-1 + HO2 <=> C4H71-3 + H2O2           'Arrhenius(A=(4.20615e-08,'cm^3/(mol*s)'), n=5...
# CH2O + HO2 <=> HCO + H2O2                 'Arrhenius(A=(4.23547e-06,'cm^3/(mol*s)'), n=5...
# NC3H7CHO + HO2 <=> NC3H7CO + H2O2         'Arrhenius(A=(7.91164e-05,'cm^3/(mol*s)'), n=4...
# C2H5COCH3 + HO2 <=> C2H5COCH2 + H2O2      'Arrhenius(A=(8.05561e-07,'cm^3/(mol*s)'), n=5...
# IC4H7OH + HO2 <=> IC4H6OH + H2O2          'Arrhenius(A=(8.37166e-09,'cm^3/(mol*s)'), n=5...
# CH3OH + HO2 <=> CH2OH + H2O2              'Arrhenius(A=(8.64717e-05,'cm^3/(mol*s)'), n=4...
# C3H4-P + HO2 <=> C3H3 + H2O2              'Arrhenius(A=(9.02065e-08,'cm^3/(mol*s)'), n=5...
# sc4h9oh + ho2 <=> sc4h8oh-3 + h2o2        'Arrhenius(A=(9.523e-05,'cm^3/(mol*s)'), n=4.5...
#
# [60 rows x 74 columns]

# %%
# %cd arrheniusPlots
# Out:
# /Users/nathan/Code/OOHAbstraction_Testing/plotOutputResults/arrheniusPlots

# %%
def evalArrhenius(autoTSTExpression):
    try:
        my_string = str(autoTSTExpression)[1:]
        result = eval(my_string, {}, {'Arrhenius': rmgpy.kinetics.Arrhenius})
    except:
        result = autoTSTExpression
    return result

Temps = np.array(range(200,2600,100))
inverseTemps = 1000./Temps

for j in expSheet.index:
    for i in list(expSheet):
        logk = []
        logkAutoTST = []
        expSheet[i].loc[j] = evalArrhenius(expSheet[i].loc[j])
        #print type(expSheet[i].loc[j])
        
        if i == 'AutoTST-OOHabstraction':
            for Temp in Temps:
                k = expSheet[i].loc[j].getRateCoefficient(Temp,1000)
                logkAutoTST.append(np.log10(k) + 6)
                
            plt.plot(inverseTemps, logkAutoTST, '-r', linewidth=2)
        elif type(expSheet[i].loc[j]) == rmgpy.kinetics.arrhenius.Arrhenius:
            #expSheet[i].loc[j]
            for Temp in Temps:
                k = expSheet[i].loc[j].getRateCoefficient(Temp,1000)
                logk.append(np.log10(k) + 6)
            plt.plot(inverseTemps, logk, ':k', linewidth=2)
    plt.xlabel("$1000/T [K^{-1}]$", fontsize=16)
    plt.ylabel("$log_{10}(k) [cm^3 / (mole \cdot s)]$", fontsize=16)
    plt.tick_params(axis='x', labelsize=11)
    plt.tick_params(axis='y', labelsize=11)
    #plt.title(j)
    plt.xlim([0.25,1.5])
    saveString = str(j) + '.pdf'
    plt.savefig(saveString)
    plt.show()

# %% [markdown]
# # My attempt to generate parity plots for $A$ and $E_a$

# %%
# %cd ..
# Out:
# /Users/nathan/Code/OOHAbstraction_Testing/plotOutputResults

# %%
for j in expSheet.index:
    #mean = kinSheet.loc[j].mean(axis=0) + 6
    
    autoTST = np.log10(float(str(expSheet['AutoTST-OOHabstraction'].loc[j].A).split(' ')[0])) + 6
    #print expSheet['AutoTST-OOHabstraction'].loc[j].A
    #print 
    x_list = []
    y_list = []
    for i in list(expSheet):
        if i != "AutoTST-OOHabstraction" and pd.isnull(kinSheet[i].loc[j]) == False:
            try:
                #print float(str(expSheet[i].loc[j].A).split(' ')[0])
                x_list.append(np.log10(float(str(expSheet[i].loc[j].A).split(' ')[0])) + 6)
                y_list.append(autoTST)
            except:
                print expSheet[i].loc[j]
            
    mean = np.mean(x_list)
    plt.plot(x_list, y_list, '-b') # Line for the range for each AutoTST point
    plt.plot(x_list, y_list, '|b') # Tick marks for each point
    plt.plot(mean, autoTST, '.k') # Dots for each average data point
    plt.plot(range(-5, 22), range(-5, 22), '-g')# Parity Line
    plt.plot(range(-6, 21), range(-5, 22), ':g') # 1 order of magnitude
    plt.plot(range(-4, 23), range(-5, 22), ':g')# 1 order of magnitude
    plt.ylim([-5,20])
    plt.xlim([-5,20])
    plt.xlabel('$log_{10}A [cm^3 / (mole \cdot s)]$ by Imported Kinetics', fontsize=10)
    plt.ylabel('$log_{10}A [cm^3 / (mole \cdot s)]$ by AutoTST', fontsize=10)
    plt.tick_params(axis='x', labelsize=8)
    plt.tick_params(axis='y', labelsize=8)

plt.savefig('parityPlotA.pdf')
# Out:
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(2e+12,'cm^3/(mol*s)'), n=0, Ea=(17010,'cal/mol'), T0=(1,'K')), Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea=(19390,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(4e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(8e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(8e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K')), Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(8e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K'))])
# /Users/nathan/anaconda/envs/rmg_env/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Users/nathan/anaconda/envs/rmg_env/lib/python2.7/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(6400,'cm^3/(mol*s)'), n=2.6, Ea=(12400,'cal/mol'), T0=(1,'K')), Arrhenius(A=(6e+11,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(6400,'cm^3/(mol*s)'), n=2.6, Ea=(12400,'cal/mol'), T0=(1,'K')), Arrhenius(A=(6e+11,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K'))])
# 'PDepArrhenius(pressures=([0.03947,1,10],'atm'), arrhenius=[MultiArrhenius(arrhenius=[Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea=(10210,'cal/mol'), T0=(1,'K')), Arrhenius(A=(-8.637e+13,'cm^3/(mol*s)'), n=0.141, Ea=(29007.4,'cal/mol'), T0=(1,'K'))]), MultiArrhenius(arrhenius=[Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea=(10210,'cal/mol'), T0=(1,'K')), Arrhenius(A=(-2.46e+14,'cm^3/(mol*s)'), n=0.027, Ea=(30123.8,'cal/mol'), T0=(1,'K'))]), MultiArrhenius(arrhenius=[Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea=(10210,'cal/mol'), T0=(1,'K')), Arrhenius(A=(-5.197e+14,'cm^3/(mol*s)'), n=-0.052, Ea=(31047.3,'cal/mol'), T0=(1,'K'))])])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(0.2404,'cm^3/(mol*s)'), n=4.086, Ea=(12842.3,'cal/mol'), T0=(1,'K')), Arrhenius(A=(6.977e-10,'cm^3/(mol*s)'), n=6.172, Ea=(7030.3,'cal/mol'), T0=(1,'K'))])

# %%
for j in expSheet.index:
    #mean = kinSheet.loc[j].mean(axis=0) + 6
    
    autoTST = np.log10(float(str(expSheet['AutoTST-OOHabstraction'].loc[j].Ea).split(' ')[0]) / 0.004184)
    #print expSheet['AutoTST-OOHabstraction'].loc[j].Ea
    #print 
    x_list = []
    y_list = []
    for i in list(expSheet):
        if i != "AutoTST-OOHabstraction" and pd.isnull(kinSheet[i].loc[j]) == False:
            try:
                #print expSheet[i].loc[j].Ea
                x_list.append(np.log10(float(str(expSheet[i].loc[j].Ea).split(' ')[0])))
                y_list.append(autoTST)
            except:
                print expSheet[i].loc[j]
            
    mean = np.mean(x_list)
    plt.plot(x_list, y_list, '-b') # Line for the range for each AutoTST point
    plt.plot(x_list, y_list, '|b') # Tick marks for each point
    plt.plot(mean, autoTST, '.k') # Dots for each average data point
    plt.plot(range(-5, 22), range(-5, 22), '-g')# Parity Line
    plt.plot(range(-6, 21), range(-5, 22), ':g') # 1 order of magnitude
    plt.plot(range(-4, 23), range(-5, 22), ':g')# 1 order of magnitude
    plt.ylim([2.5,5])
    plt.xlim([2.5,5])
    plt.xlabel('$E_a [cal / mol]$ by Imported Kinetics', fontsize=10)
    plt.ylabel('$E_a [cal / mol]$ by AutoTST', fontsize=10)
    plt.tick_params(axis='x', labelsize=8)
    plt.tick_params(axis='y', labelsize=8)

plt.savefig('parityPlotEa.pdf')
# Out:
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(2e+12,'cm^3/(mol*s)'), n=0, Ea=(17010,'cal/mol'), T0=(1,'K')), Arrhenius(A=(1.7e+13,'cm^3/(mol*s)'), n=0, Ea=(19390,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(4e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(8e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(8e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K')), Arrhenius(A=(1.2e+12,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K')), Arrhenius(A=(8e+11,'cm^3/(mol*s)'), n=0, Ea=(15500,'cal/mol'), T0=(1,'K'))])
# /Users/nathan/anaconda/envs/rmg_env/lib/python2.7/site-packages/ipykernel/__main__.py:13: RuntimeWarning: divide by zero encountered in log10
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(6400,'cm^3/(mol*s)'), n=2.6, Ea=(12400,'cal/mol'), T0=(1,'K')), Arrhenius(A=(6e+11,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K'))])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(6400,'cm^3/(mol*s)'), n=2.6, Ea=(12400,'cal/mol'), T0=(1,'K')), Arrhenius(A=(6e+11,'cm^3/(mol*s)'), n=0, Ea=(17000,'cal/mol'), T0=(1,'K'))])
# 'PDepArrhenius(pressures=([0.03947,1,10],'atm'), arrhenius=[MultiArrhenius(arrhenius=[Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea=(10210,'cal/mol'), T0=(1,'K')), Arrhenius(A=(-8.637e+13,'cm^3/(mol*s)'), n=0.141, Ea=(29007.4,'cal/mol'), T0=(1,'K'))]), MultiArrhenius(arrhenius=[Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea=(10210,'cal/mol'), T0=(1,'K')), Arrhenius(A=(-2.46e+14,'cm^3/(mol*s)'), n=0.027, Ea=(30123.8,'cal/mol'), T0=(1,'K'))]), MultiArrhenius(arrhenius=[Arrhenius(A=(41100,'cm^3/(mol*s)'), n=2.5, Ea=(10210,'cal/mol'), T0=(1,'K')), Arrhenius(A=(-5.197e+14,'cm^3/(mol*s)'), n=-0.052, Ea=(31047.3,'cal/mol'), T0=(1,'K'))])])
# 'MultiArrhenius(arrhenius=[Arrhenius(A=(0.2404,'cm^3/(mol*s)'), n=4.086, Ea=(12842.3,'cal/mol'), T0=(1,'K')), Arrhenius(A=(6.977e-10,'cm^3/(mol*s)'), n=6.172, Ea=(7030.3,'cal/mol'), T0=(1,'K'))])
